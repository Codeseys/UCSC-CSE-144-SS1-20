# %% [markdown]
# # Assignment 3
#
# Turn in the assignment via Canvas.
#
# To write legible answers you will need to be familiar with both [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) and [Latex](https://www.latex-tutorial.com/tutorials/amsmath/)
#
# Before you turn this problem in, make sure everything runs as expected. First, restart the kernel (in the menubar, select Kernel→→Restart) and then run all cells (in the menubar, select Cell→→Run All).
#
# Make sure you fill in any place that says "YOUR CODE HERE" or "YOUR ANSWER HERE", as well as your name below:

# %%
NAME = "Baladithya Balamurugan"
STUDENT_ID = "1699864"

# %% [markdown]
# # 1) Binary Classification
# ## i) Logistic Regression
# In this task, we will run logistic regression using scikit learn. But first the dataset needs to be created. Call this data set the Gaussian Quantile Dataset.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.datasets import make_gaussian_quantiles
np.random.seed(111)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Construct dataset
X, y = make_gaussian_quantiles(cov=4.,
                                 n_samples=500, n_features=1,
                                 n_classes=2, random_state=1)
# Making X1 values, reshape y1, and creating random noise for x1 values
X = X-3.0  
noise = np.random.normal(loc=0.0, scale=0.4, size=len(X)).reshape(-1,1)
y = y.reshape(-1,1)
X = np.sum([X,noise],axis=0)

# %%
# The dataset
print(np.concatenate((X,y), axis=1, out=None))
# Out:
# [[-2.42338811e+00  0.00000000e+00]
#  [ 1.53512714e+00  1.00000000e+00]
#  [-2.97599422e+00  0.00000000e+00]
#  [ 4.78916909e-01  1.00000000e+00]
#  [-1.60960529e+00  1.00000000e+00]
#  [-3.55691511e+00  0.00000000e+00]
#  [-3.86154330e+00  0.00000000e+00]
#  [-3.07094921e+00  0.00000000e+00]
#  [ 2.76750500e+00  1.00000000e+00]
#  [-2.41581646e+00  0.00000000e+00]
#  [-4.62707507e+00  1.00000000e+00]
#  [-4.74476399e+00  1.00000000e+00]
#  [-3.00505940e+00  0.00000000e+00]
#  [ 5.43380441e-01  1.00000000e+00]
#  [-5.55712418e+00  1.00000000e+00]
#  [-1.41449115e+00  1.00000000e+00]
#  [-2.27826391e+00  0.00000000e+00]
#  [-1.94740223e+00  0.00000000e+00]
#  [-2.46007512e+00  0.00000000e+00]
#  [-3.76786255e+00  0.00000000e+00]
#  [-7.59123156e-01  1.00000000e+00]
#  [-3.92296941e+00  0.00000000e+00]
#  [-1.40830029e+00  1.00000000e+00]
#  [-3.51714486e+00  0.00000000e+00]
#  [-6.91583977e-01  1.00000000e+00]
#  [-3.25406548e+00  0.00000000e+00]
#  [-4.70192512e+00  0.00000000e+00]
#  [-2.88430556e+00  0.00000000e+00]
#  [-3.82868876e+00  0.00000000e+00]
#  [-3.60400991e-01  1.00000000e+00]
#  [-6.66456109e+00  1.00000000e+00]
#  [-4.78099987e+00  1.00000000e+00]
#  [-1.78596116e+00  1.00000000e+00]
#  [-1.41492005e-01  1.00000000e+00]
#  [-6.37809602e-01  1.00000000e+00]
#  [-2.48720638e+00  0.00000000e+00]
#  [ 1.08349034e+00  1.00000000e+00]
#  [-2.90674484e+00  0.00000000e+00]
#  [-2.37943799e+00  0.00000000e+00]
#  [-3.04426113e+00  0.00000000e+00]
#  [-1.75114584e+00  1.00000000e+00]
#  [-1.31106928e+00  1.00000000e+00]
#  [-3.59129260e+00  0.00000000e+00]
#  [-3.36051923e+00  0.00000000e+00]
#  [-3.97867615e+00  0.00000000e+00]
#  [-5.00806191e+00  1.00000000e+00]
#  [-2.67797355e+00  0.00000000e+00]
#  [-1.17774258e+00  1.00000000e+00]
#  [-3.17578094e+00  0.00000000e+00]
#  [-8.34086510e+00  1.00000000e+00]
#  [-4.69215016e+00  1.00000000e+00]
#  [-4.72072708e+00  1.00000000e+00]
#  [-2.79082805e+00  0.00000000e+00]
#  [-3.67630551e+00  0.00000000e+00]
#  [-3.71451248e+00  0.00000000e+00]
#  [-3.80044531e+00  0.00000000e+00]
#  [-3.22549530e+00  0.00000000e+00]
#  [-3.89688775e+00  1.00000000e+00]
#  [-2.92101492e+00  0.00000000e+00]
#  [-2.60597718e+00  0.00000000e+00]
#  [-2.20079525e+00  0.00000000e+00]
#  [-2.62121238e+00  0.00000000e+00]
#  [-5.38769320e+00  1.00000000e+00]
#  [-3.08269940e+00  0.00000000e+00]
#  [-3.16197726e+00  0.00000000e+00]
#  [ 7.05889606e-01  1.00000000e+00]
#  [-7.33526992e+00  1.00000000e+00]
#  [-5.54998301e+00  1.00000000e+00]
#  [-2.32227522e-01  1.00000000e+00]
#  [-1.22745100e+00  1.00000000e+00]
#  [-4.99570882e+00  1.00000000e+00]
#  [-4.29842738e+00  1.00000000e+00]
#  [-6.83059970e+00  1.00000000e+00]
#  [-7.67863833e-01  1.00000000e+00]
#  [-3.41406793e+00  0.00000000e+00]
#  [-3.73846357e+00  0.00000000e+00]
#  [-1.83206160e+00  0.00000000e+00]
#  [-5.07154524e+00  1.00000000e+00]
#  [-2.43974314e+00  0.00000000e+00]
#  [-2.49269014e+00  0.00000000e+00]
#  [-3.70631635e+00  0.00000000e+00]
#  [-2.15399972e+00  0.00000000e+00]
#  [-5.04894497e+00  1.00000000e+00]
#  [-8.23848102e-01  1.00000000e+00]
#  [-4.31693341e+00  1.00000000e+00]
#  [ 8.60893285e-01  1.00000000e+00]
#  [-3.43153949e+00  0.00000000e+00]
#  [-5.55562089e+00  1.00000000e+00]
#  [-1.14591263e+00  1.00000000e+00]
#  [-6.09732604e+00  1.00000000e+00]
#  [-4.90396727e+00  1.00000000e+00]
#  [-3.89485620e+00  1.00000000e+00]
#  [-5.51515317e+00  1.00000000e+00]
#  [ 7.66076940e-01  1.00000000e+00]
#  [-8.39082007e-02  1.00000000e+00]
#  [-7.15328437e-01  1.00000000e+00]
#  [-4.08272527e+00  0.00000000e+00]
#  [-2.17451276e+00  0.00000000e+00]
#  [-4.86837635e+00  0.00000000e+00]
#  [-1.53786733e+00  1.00000000e+00]
#  [-3.64621959e+00  0.00000000e+00]
#  [ 1.11816292e+00  1.00000000e+00]
#  [-4.38975676e+00  1.00000000e+00]
#  [-2.02483538e+00  1.00000000e+00]
#  [-4.91624155e+00  1.00000000e+00]
#  [-3.20540604e+00  0.00000000e+00]
#  [-6.50767723e+00  1.00000000e+00]
#  [ 5.66094603e-01  1.00000000e+00]
#  [-5.81549034e+00  1.00000000e+00]
#  [-2.76990269e+00  0.00000000e+00]
#  [-1.50617117e+00  0.00000000e+00]
#  [-4.84958371e+00  1.00000000e+00]
#  [-1.73696722e+00  0.00000000e+00]
#  [-3.17506998e+00  0.00000000e+00]
#  [-1.12256336e+00  1.00000000e+00]
#  [-6.82408037e+00  1.00000000e+00]
#  [-4.60467195e+00  1.00000000e+00]
#  [ 1.76040317e+00  1.00000000e+00]
#  [-2.29246561e+00  0.00000000e+00]
#  [-5.49745030e-01  1.00000000e+00]
#  [-3.16631699e+00  0.00000000e+00]
#  [-2.52677491e+00  0.00000000e+00]
#  [-2.24129038e+00  0.00000000e+00]
#  [-5.61034517e+00  1.00000000e+00]
#  [-1.00895521e+00  1.00000000e+00]
#  [-9.14911816e-01  1.00000000e+00]
#  [-5.32327875e-01  1.00000000e+00]
#  [ 9.74874549e-01  1.00000000e+00]
#  [-4.10910791e+00  0.00000000e+00]
#  [-2.23104553e+00  0.00000000e+00]
#  [-5.54449452e+00  1.00000000e+00]
#  [-3.36713342e+00  0.00000000e+00]
#  [-9.44993219e-01  1.00000000e+00]
#  [-5.63019792e+00  1.00000000e+00]
#  [-1.86024671e+00  0.00000000e+00]
#  [-2.65977759e+00  0.00000000e+00]
#  [-1.17829749e+00  1.00000000e+00]
#  [-4.81607587e+00  1.00000000e+00]
#  [-3.96265323e+00  0.00000000e+00]
#  [ 1.41353601e-01  1.00000000e+00]
#  [-4.66998839e+00  0.00000000e+00]
#  [-2.60008341e+00  0.00000000e+00]
#  [-7.82737723e-03  1.00000000e+00]
#  [-4.57594332e+00  1.00000000e+00]
#  [-1.87429665e+00  0.00000000e+00]
#  [-1.57851247e+00  0.00000000e+00]
#  [-3.77873222e+00  0.00000000e+00]
#  [-4.46535774e-01  1.00000000e+00]
#  [-4.51510509e+00  1.00000000e+00]
#  [-2.88383019e+00  0.00000000e+00]
#  [-4.59225669e+00  0.00000000e+00]
#  [-2.48852287e+00  0.00000000e+00]
#  [-1.57589087e+00  1.00000000e+00]
#  [-3.68492738e+00  0.00000000e+00]
#  [-2.67199213e+00  0.00000000e+00]
#  [-4.56004468e+00  1.00000000e+00]
#  [-1.77073022e+00  1.00000000e+00]
#  [-7.75056411e-01  1.00000000e+00]
#  [-4.29463631e+00  1.00000000e+00]
#  [-2.25683023e+00  0.00000000e+00]
#  [-2.02736724e+00  0.00000000e+00]
#  [-2.08596832e+00  0.00000000e+00]
#  [-2.12056247e+00  0.00000000e+00]
#  [-1.49484221e+00  1.00000000e+00]
#  [-3.55524144e+00  0.00000000e+00]
#  [-3.93125874e+00  0.00000000e+00]
#  [-5.02481406e+00  0.00000000e+00]
#  [-6.83217630e+00  1.00000000e+00]
#  [-2.77869949e+00  0.00000000e+00]
#  [-6.40746336e+00  1.00000000e+00]
#  [-3.09735811e+00  0.00000000e+00]
#  [-4.03537732e+00  0.00000000e+00]
#  [-3.35051372e+00  0.00000000e+00]
#  [-2.94358007e+00  0.00000000e+00]
#  [-2.82369950e+00  0.00000000e+00]
#  [-1.40338153e+00  1.00000000e+00]
#  [-5.67597415e+00  1.00000000e+00]
#  [-4.02281243e+00  0.00000000e+00]
#  [-1.31766979e+00  1.00000000e+00]
#  [-6.34645402e+00  1.00000000e+00]
#  [-3.00555118e+00  0.00000000e+00]
#  [ 3.88017990e-01  1.00000000e+00]
#  [ 8.17664950e-01  1.00000000e+00]
#  [-2.05139307e+00  0.00000000e+00]
#  [-5.39761484e+00  1.00000000e+00]
#  [-2.99462264e+00  0.00000000e+00]
#  [-2.51530713e+00  0.00000000e+00]
#  [-4.32320344e+00  1.00000000e+00]
#  [-3.33086808e+00  0.00000000e+00]
#  [ 2.05091625e+00  1.00000000e+00]
#  [-8.08548890e-01  1.00000000e+00]
#  [-4.85701732e+00  1.00000000e+00]
#  [-3.49161823e+00  0.00000000e+00]
#  [-5.21874710e+00  1.00000000e+00]
#  [ 7.49587140e-01  1.00000000e+00]
#  [-3.62891547e+00  0.00000000e+00]
#  [-3.49148381e+00  0.00000000e+00]
#  [-3.23036499e-01  1.00000000e+00]
#  [-5.54629072e+00  1.00000000e+00]
#  [-6.11178068e+00  1.00000000e+00]
#  [-7.16551088e+00  1.00000000e+00]
#  [-4.68076582e+00  0.00000000e+00]
#  [-6.21327680e+00  1.00000000e+00]
#  [-3.67441644e+00  0.00000000e+00]
#  [-4.37034621e+00  1.00000000e+00]
#  [-1.54414654e+00  1.00000000e+00]
#  [-3.89898760e+00  0.00000000e+00]
#  [-4.73480724e+00  0.00000000e+00]
#  [-7.10537571e+00  1.00000000e+00]
#  [-3.54751713e+00  0.00000000e+00]
#  [-3.61837361e+00  0.00000000e+00]
#  [-4.15716940e+00  0.00000000e+00]
#  [-1.97727695e+00  0.00000000e+00]
#  [-2.13475092e+00  0.00000000e+00]
#  [ 2.18302059e+00  1.00000000e+00]
#  [-3.27063884e+00  0.00000000e+00]
#  [-2.09641976e+00  0.00000000e+00]
#  [-4.09798455e+00  0.00000000e+00]
#  [-2.70694167e+00  0.00000000e+00]
#  [-3.72839642e+00  0.00000000e+00]
#  [-2.16391476e+00  0.00000000e+00]
#  [-2.33823207e+00  0.00000000e+00]
#  [-3.49096891e+00  0.00000000e+00]
#  [-6.83972239e-01  1.00000000e+00]
#  [-3.10283208e+00  0.00000000e+00]
#  [-3.77574665e+00  0.00000000e+00]
#  [-1.42751551e+00  1.00000000e+00]
#  [-7.57285331e+00  1.00000000e+00]
#  [-4.21072535e+00  1.00000000e+00]
#  [-5.60477208e+00  1.00000000e+00]
#  [-3.19116825e+00  0.00000000e+00]
#  [ 7.83671803e-01  1.00000000e+00]
#  [-2.77988608e+00  0.00000000e+00]
#  [-4.37628989e+00  0.00000000e+00]
#  [-2.91415951e+00  0.00000000e+00]
#  [-4.48232434e+00  1.00000000e+00]
#  [-4.91838128e+00  0.00000000e+00]
#  [-3.43826595e+00  0.00000000e+00]
#  [-4.42897402e-01  1.00000000e+00]
#  [-1.24702108e+00  0.00000000e+00]
#  [-4.81384002e+00  1.00000000e+00]
#  [-1.37991743e+00  1.00000000e+00]
#  [-5.54971318e+00  1.00000000e+00]
#  [-3.47423561e+00  0.00000000e+00]
#  [-3.50984906e+00  0.00000000e+00]
#  [-2.42111994e+00  0.00000000e+00]
#  [-5.49881478e-01  1.00000000e+00]
#  [-5.33360736e-01  1.00000000e+00]
#  [-2.62988876e+00  0.00000000e+00]
#  [-4.14801589e+00  0.00000000e+00]
#  [-4.25368730e+00  0.00000000e+00]
#  [-1.11135334e+00  1.00000000e+00]
#  [-3.01485390e+00  0.00000000e+00]
#  [-3.79490766e+00  0.00000000e+00]
#  [-8.46022210e-01  1.00000000e+00]
#  [-4.70937522e-01  1.00000000e+00]
#  [ 3.06204794e-01  1.00000000e+00]
#  [-3.58021815e+00  0.00000000e+00]
#  [-2.12824165e+00  0.00000000e+00]
#  [-3.89167352e+00  1.00000000e+00]
#  [-3.35304615e+00  0.00000000e+00]
#  [-1.19028233e+00  1.00000000e+00]
#  [-7.93705994e-01  1.00000000e+00]
#  [-3.25526661e+00  0.00000000e+00]
#  [-3.70408218e+00  0.00000000e+00]
#  [-2.74001420e+00  0.00000000e+00]
#  [-2.62454608e+00  0.00000000e+00]
#  [-1.81200760e+00  0.00000000e+00]
#  [-5.79411648e+00  1.00000000e+00]
#  [-2.77665636e+00  0.00000000e+00]
#  [-1.85466228e+00  0.00000000e+00]
#  [-4.30173544e+00  1.00000000e+00]
#  [-5.79472946e+00  1.00000000e+00]
#  [-1.76779194e+00  0.00000000e+00]
#  [-3.71100160e+00  0.00000000e+00]
#  [-6.79068523e+00  1.00000000e+00]
#  [-3.68726664e+00  0.00000000e+00]
#  [-1.32649745e+00  1.00000000e+00]
#  [-3.20236669e+00  0.00000000e+00]
#  [-3.78894330e+00  0.00000000e+00]
#  [-4.50323902e+00  1.00000000e+00]
#  [ 7.97527323e-01  1.00000000e+00]
#  [-4.95132307e+00  1.00000000e+00]
#  [-1.99876834e+00  0.00000000e+00]
#  [ 9.84705957e-01  1.00000000e+00]
#  [-5.38284428e+00  1.00000000e+00]
#  [-4.65375004e+00  0.00000000e+00]
#  [ 1.15715908e+00  1.00000000e+00]
#  [-6.89770012e+00  1.00000000e+00]
#  [ 1.54430028e+00  1.00000000e+00]
#  [-5.27875548e-01  1.00000000e+00]
#  [-3.82428786e+00  0.00000000e+00]
#  [-4.99452635e+00  1.00000000e+00]
#  [-3.40194554e+00  0.00000000e+00]
#  [-3.85693950e+00  0.00000000e+00]
#  [-1.91442588e+00  0.00000000e+00]
#  [-1.87752184e+00  1.00000000e+00]
#  [-6.65578183e-01  1.00000000e+00]
#  [-2.35853646e+00  0.00000000e+00]
#  [-1.43176463e+00  1.00000000e+00]
#  [-1.63336726e+00  1.00000000e+00]
#  [-2.10400808e+00  0.00000000e+00]
#  [-3.82029165e+00  1.00000000e+00]
#  [-3.96112712e+00  0.00000000e+00]
#  [-2.47990816e+00  0.00000000e+00]
#  [-2.57227075e+00  0.00000000e+00]
#  [-3.82485866e+00  0.00000000e+00]
#  [-7.15925381e-01  1.00000000e+00]
#  [-3.61572938e+00  0.00000000e+00]
#  [ 1.03994036e+00  1.00000000e+00]
#  [-1.38957236e+00  1.00000000e+00]
#  [-2.22510907e+00  0.00000000e+00]
#  [-3.19410607e+00  0.00000000e+00]
#  [-6.88294402e+00  1.00000000e+00]
#  [-3.08065099e+00  0.00000000e+00]
#  [-1.07449205e+00  1.00000000e+00]
#  [-3.82605761e+00  0.00000000e+00]
#  [-4.82976994e+00  1.00000000e+00]
#  [-2.59321678e+00  0.00000000e+00]
#  [-4.90055723e-01  1.00000000e+00]
#  [-1.41768396e+00  0.00000000e+00]
#  [-3.81399837e+00  0.00000000e+00]
#  [-1.56218158e+00  1.00000000e+00]
#  [-4.33389840e+00  1.00000000e+00]
#  [-3.80984777e+00  0.00000000e+00]
#  [-2.21464686e+00  0.00000000e+00]
#  [-5.47313925e+00  1.00000000e+00]
#  [-7.25402106e+00  1.00000000e+00]
#  [-2.66127925e+00  0.00000000e+00]
#  [-1.45022822e+00  1.00000000e+00]
#  [-3.02588179e+00  0.00000000e+00]
#  [-4.12172069e+00  0.00000000e+00]
#  [-3.46118884e-01  1.00000000e+00]
#  [-4.50985308e+00  0.00000000e+00]
#  [-1.04345906e+00  1.00000000e+00]
#  [-4.73194868e+00  1.00000000e+00]
#  [-4.41371098e+00  1.00000000e+00]
#  [-1.09122855e+00  1.00000000e+00]
#  [-1.43939418e+00  1.00000000e+00]
#  [-2.52012070e+00  0.00000000e+00]
#  [-6.03870154e-01  1.00000000e+00]
#  [-3.13379522e+00  0.00000000e+00]
#  [-2.73846845e+00  0.00000000e+00]
#  [-4.45832436e+00  0.00000000e+00]
#  [-4.22424477e+00  0.00000000e+00]
#  [-8.28903907e-01  1.00000000e+00]
#  [-4.01518170e+00  0.00000000e+00]
#  [-2.69923537e+00  0.00000000e+00]
#  [-7.85466253e+00  1.00000000e+00]
#  [-3.86245134e-01  1.00000000e+00]
#  [-5.57256526e+00  1.00000000e+00]
#  [-2.25911688e+00  0.00000000e+00]
#  [ 5.18062361e-03  1.00000000e+00]
#  [-2.35288413e+00  0.00000000e+00]
#  [-6.16633120e+00  1.00000000e+00]
#  [-3.72700376e+00  0.00000000e+00]
#  [-5.87156926e+00  1.00000000e+00]
#  [-2.28665563e+00  0.00000000e+00]
#  [-6.43879035e+00  1.00000000e+00]
#  [-1.86248480e+00  0.00000000e+00]
#  [-3.90983881e+00  0.00000000e+00]
#  [-1.60017272e+00  1.00000000e+00]
#  [-4.08139780e+00  0.00000000e+00]
#  [-6.52470261e+00  1.00000000e+00]
#  [-4.35450078e+00  1.00000000e+00]
#  [-5.05486389e+00  0.00000000e+00]
#  [-1.89212909e+00  0.00000000e+00]
#  [-6.02077878e+00  1.00000000e+00]
#  [-2.33537719e+00  0.00000000e+00]
#  [-1.94452141e+00  0.00000000e+00]
#  [-4.50133901e+00  0.00000000e+00]
#  [-4.28788164e+00  0.00000000e+00]
#  [-1.22453784e+00  1.00000000e+00]
#  [-1.83340272e+00  1.00000000e+00]
#  [-1.46411036e+00  1.00000000e+00]
#  [-3.86526574e+00  0.00000000e+00]
#  [-5.30004119e+00  1.00000000e+00]
#  [-6.21457188e-01  1.00000000e+00]
#  [-4.84130434e+00  1.00000000e+00]
#  [-2.37174327e+00  0.00000000e+00]
#  [-4.60017004e+00  1.00000000e+00]
#  [-4.50726295e-01  1.00000000e+00]
#  [-1.95587790e+00  0.00000000e+00]
#  [-3.29067218e+00  0.00000000e+00]
#  [-2.96619510e+00  0.00000000e+00]
#  [-3.60811513e+00  0.00000000e+00]
#  [-3.23319805e+00  0.00000000e+00]
#  [-2.70025538e+00  0.00000000e+00]
#  [-3.98986854e+00  1.00000000e+00]
#  [-8.42377486e+00  1.00000000e+00]
#  [-2.51981993e+00  0.00000000e+00]
#  [-4.68822875e+00  1.00000000e+00]
#  [-1.93294422e-01  1.00000000e+00]
#  [-2.65557721e+00  0.00000000e+00]
#  [-1.69600227e+00  0.00000000e+00]
#  [-5.72116396e+00  1.00000000e+00]
#  [-2.94514108e+00  0.00000000e+00]
#  [-4.81193902e+00  1.00000000e+00]
#  [-1.63161265e+00  0.00000000e+00]
#  [-2.12935731e+00  0.00000000e+00]
#  [-9.15635679e-01  1.00000000e+00]
#  [-1.78632323e+00  0.00000000e+00]
#  [-4.18559760e+00  0.00000000e+00]
#  [-3.76671865e+00  0.00000000e+00]
#  [-2.22109045e+00  0.00000000e+00]
#  [-8.97135100e+00  1.00000000e+00]
#  [-5.67832419e+00  1.00000000e+00]
#  [-2.12397740e+00  0.00000000e+00]
#  [-5.29505377e+00  1.00000000e+00]
#  [-1.09014623e+00  1.00000000e+00]
#  [-2.89454528e+00  0.00000000e+00]
#  [-5.60222978e+00  1.00000000e+00]
#  [-4.53949037e+00  1.00000000e+00]
#  [-6.15898685e-01  1.00000000e+00]
#  [-1.33915308e+00  0.00000000e+00]
#  [-3.75093253e+00  0.00000000e+00]
#  [-3.12616261e+00  0.00000000e+00]
#  [-6.93627522e+00  1.00000000e+00]
#  [-1.91116524e+00  0.00000000e+00]
#  [-4.96533199e+00  1.00000000e+00]
#  [-3.35742538e+00  0.00000000e+00]
#  [ 3.64066494e-01  1.00000000e+00]
#  [-9.59021871e-01  1.00000000e+00]
#  [-7.45821837e+00  1.00000000e+00]
#  [-7.34198126e+00  1.00000000e+00]
#  [-3.12079781e+00  0.00000000e+00]
#  [-3.43000133e+00  0.00000000e+00]
#  [-5.67009506e+00  1.00000000e+00]
#  [ 2.29280430e-02  1.00000000e+00]
#  [-4.24237988e+00  0.00000000e+00]
#  [-1.66606888e+00  0.00000000e+00]
#  [ 1.27698198e+00  1.00000000e+00]
#  [-2.60721012e+00  0.00000000e+00]
#  [-1.05914867e+00  1.00000000e+00]
#  [-9.03993989e-01  1.00000000e+00]
#  [-2.98199937e+00  0.00000000e+00]
#  [-1.60152186e+00  0.00000000e+00]
#  [-1.75344280e+00  1.00000000e+00]
#  [-4.97244186e+00  1.00000000e+00]
#  [ 4.52027417e-01  1.00000000e+00]
#  [-3.62231678e+00  0.00000000e+00]
#  [-9.54285585e-01  1.00000000e+00]
#  [-1.51800589e+00  0.00000000e+00]
#  [-6.57003396e-01  1.00000000e+00]
#  [-3.88005438e+00  0.00000000e+00]
#  [-2.61482329e+00  0.00000000e+00]
#  [-1.92727903e+00  0.00000000e+00]
#  [-4.89083006e+00  1.00000000e+00]
#  [-1.38218711e+00  1.00000000e+00]
#  [ 9.43724695e-01  1.00000000e+00]
#  [-2.08867655e+00  0.00000000e+00]
#  [-3.56058567e+00  0.00000000e+00]
#  [-3.21092294e+00  0.00000000e+00]
#  [-5.69064089e+00  1.00000000e+00]
#  [-7.61903371e-01  1.00000000e+00]
#  [-1.55932180e+00  0.00000000e+00]
#  [-4.63831048e+00  1.00000000e+00]
#  [ 1.14010130e+00  1.00000000e+00]
#  [ 7.25753205e-01  1.00000000e+00]
#  [-4.23644848e-01  1.00000000e+00]
#  [-3.53922323e+00  0.00000000e+00]
#  [-3.53976580e+00  0.00000000e+00]
#  [-3.29908857e+00  0.00000000e+00]
#  [-7.87583908e+00  1.00000000e+00]
#  [-7.45584674e+00  1.00000000e+00]
#  [-4.05409285e+00  0.00000000e+00]
#  [-4.15472980e+00  0.00000000e+00]
#  [-5.56170832e-01  1.00000000e+00]
#  [-1.77022844e+00  1.00000000e+00]
#  [-4.70937461e+00  1.00000000e+00]
#  [-4.47254791e+00  0.00000000e+00]
#  [-7.29743437e-01  0.00000000e+00]
#  [-4.19245656e+00  1.00000000e+00]
#  [-1.77217721e+00  1.00000000e+00]
#  [-4.17469629e+00  1.00000000e+00]
#  [-2.98052873e+00  0.00000000e+00]
#  [-1.31794264e+00  1.00000000e+00]
#  [ 2.92799509e-01  1.00000000e+00]
#  [-1.62356229e+00  0.00000000e+00]
#  [-3.51322386e+00  0.00000000e+00]
#  [ 9.30366724e-01  1.00000000e+00]
#  [-1.36242148e+00  1.00000000e+00]
#  [-4.70674762e+00  1.00000000e+00]
#  [ 2.42354820e+00  1.00000000e+00]
#  [-6.61480668e+00  1.00000000e+00]
#  [-2.22991737e+00  0.00000000e+00]
#  [-3.42940428e+00  0.00000000e+00]
#  [-1.67522600e+00  1.00000000e+00]
#  [-1.31273891e+00  1.00000000e+00]
#  [-1.11879934e+00  1.00000000e+00]
#  [ 6.51803333e-01  1.00000000e+00]
#  [-2.21609657e-01  1.00000000e+00]
#  [-2.52058094e+00  0.00000000e+00]
#  [-1.35470295e+00  1.00000000e+00]
#  [-1.75225101e+00  0.00000000e+00]
#  [-2.69637633e+00  0.00000000e+00]
#  [-5.73806484e+00  1.00000000e+00]
#  [-2.83125403e+00  0.00000000e+00]
#  [-2.30131441e+00  0.00000000e+00]
#  [-2.66151580e+00  0.00000000e+00]]

# %%
plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], np.zeros(len(X)), c=y)

# plt.plot(x_test, clf.coef_ * x_test + clf.intercept_, linewidth=3)
plt.title('Plot of Gaussian Quantile Dataset')
plt.show()

# %% [markdown]
# Above is a plot of the dataset we created. Yellow dots are class 1 and purple dots are class 0.
# ### i.a.) Comment on how do you think logistic regression will perform when trying to classify this dataset.

# %% [markdown]
# #### Answer
# Looking at the plot, it seems that the logistic regression may form a center column that causes a double decision boundary that is just class 0 area sandwiched by class 1 area(s). With more training epochs the boundaries may shift and no necessarily be straight vertical lines.

# %% [markdown]
# ### i.b.) Implement Logistic Regression
# Implement logistic regression using scikit learn on the dataset we created and train the model. You may refer to https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html for more information on scikit learn logistic regression. \\
# ** Hint: look up in the documentation how you can adjust the penalty parameter to 'l2' or 'l1' regularization, the parameter C (the same as $\lambda$ in linear regression), or adjusting max_iter.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=144) # use the sklearn train test split function to generate the training and test sets.
clf = LogisticRegression(random_state=144,solver='liblinear',max_iter=10000,C=1,penalty='l2').fit(x_train, y_train)# Call logistic regression form sklearn
print('Training Score: ', clf.score(x_train, y_train))
print('Testing Score: ', clf.score(x_test, y_test))
# Out:
# Training Score:  0.7375
# Testing Score:  0.68
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Plot results
plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], np.zeros(len(X)), c=y)

plt.plot(x_test, clf.coef_ * x_test + clf.intercept_, linewidth=3)
plt.title('Plot of Gaussian Quantile Dataset and Regression Line')
plt.show()

# %% [markdown]
# ### i.c) How did we do?
#
# Please comment on the performance of the model you trained on training and test sets. Did you try adjusting the parameters? If so, did they help?

# %% [markdown]
# #### Answer
# Unlike what I originally thought the logistic regression to be looking like, the simple logistic regression performed here has an accuracy of around 68-73% which isn't relativly bad but it can be better. I tried adjusting the regularization parameter "C", the algorithm in which the logistic regression is performed with and the penalty method. I then settled on using the algorithm 'liblinear' as it is not much different in results from 'sag' or 'saga' and for smaller datasets it is faster. Also through trial and error I settled on the random state value of 144 because that was the value that resulted in the highest accuracy.

# %% [markdown]
# ## ii) Polynomial Transformation + Sign Classification
# Let's try some other models and see if they perform better. Recall from lecture the Binary "Sign" Classifier:
# $$\begin{align}
# f(x)= sign({\bf{\theta}}\cdot\phi(x))=\begin{cases}
#           1 & 0\leq {\bf{\theta}} \cdot\phi(x)  \\
#           0 & {\bf{\theta}} \cdot\phi(x) < 0
#             \end{cases}
# \end{align}
# $$
# We will now use Binary Sign Classifier, along with polynomial and horizontal translation in order to learn out dataset. In the next couple of sections we will illustrate how to use polynomial and horizontal translation in order use the Sign Binary Classifier. \\
# ** Note that we will classify an example as 1 if $0\leq {\bf{\theta}} \cdot\phi(x)$

# %% [markdown]
# ### Polynomial transformation example
# Let us first generate an example dataset.

# %%
# Create example data
example_data = np.arange(-3,3,0.1).reshape(-1,1)
# We will create some example labels. y=1 if x<-1 and 1<x and 0 otherwise
example_y = np.array([1 if 1<x or x<-1 else 0 for x in example_data])

# %% [markdown]
# From the plot below, we can see that this second data set is much like the dataset in part i.

# %%
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(8,8))
plt.scatter(np.arange(-3,3,0.1).reshape(-1,1),np.zeros(len(example_data)), c=example_y)
plt.title('Plot of Example Dataset')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Next, we'll now begin implementing the polynomial transformation. We begin by using scikit learn to carry polynomial transform on an example dataset. We'll also define the score variable $\hat{y_i}={\bf{\theta}}\cdot\phi(x)$ as:
#
# $$
# \begin{align}
# \hat{y_i}={\bf{\theta}}\cdot\phi(x_i) &= \theta_{0} + \theta_{1} \phi_1(x_i)+\theta_{2} \phi_2(x_i)+...+\theta_{d} \phi_d(x_i) \\
# &=\theta_{0} + \theta_{1} x_i+\theta_{2} x_i^2+...+\theta_{d} x_i^d
# \end{align}
# $$
# where $i$ is the sample number $\phi_j(x)=x^j$, where $j$ is a power, and ${\bf{\theta}}$ is a weight vector that is the length of $d$ (more on ${\bf{\theta}}$ later). To tie it all back together, the $i^{th}$ sample will be labelled as 1 if $0 \leq \hat{y}_i$ and 0 if $0>\hat{y}_i$.
#
# \\
#
# The first step will then be to compute the polynomial transform. Our data is in the form
# $$X =
# \begin{bmatrix}
#     x_{1}\\
#     x_{2}\\
#     \vdots \\
#     x_{n}
# \end{bmatrix}$$
# Using second degree polynomials we transform it into:
# $$X =\begin{bmatrix}
#     1&x_{1} & x_{1}^2\\
#     1&x_{2}& x_{2}^2\\
#     \vdots & \vdots & \vdots \\
#     1&x_{n}& x_{n}^2
# \end{bmatrix}$$
# More information here on scikit learn polynomial transformation: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(2) # We will use a polynomial of 2nd degree for this example.

# %%
# Next we fit the polynomial transform
example_X = poly.fit_transform(example_data)

# %%
example_data
# Out:
# array([[-3.00000000e+00],
#        [-2.90000000e+00],
#        [-2.80000000e+00],
#        [-2.70000000e+00],
#        [-2.60000000e+00],
#        [-2.50000000e+00],
#        [-2.40000000e+00],
#        [-2.30000000e+00],
#        [-2.20000000e+00],
#        [-2.10000000e+00],
#        [-2.00000000e+00],
#        [-1.90000000e+00],
#        [-1.80000000e+00],
#        [-1.70000000e+00],
#        [-1.60000000e+00],
#        [-1.50000000e+00],
#        [-1.40000000e+00],
#        [-1.30000000e+00],
#        [-1.20000000e+00],
#        [-1.10000000e+00],
#        [-1.00000000e+00],
#        [-9.00000000e-01],
#        [-8.00000000e-01],
#        [-7.00000000e-01],
#        [-6.00000000e-01],
#        [-5.00000000e-01],
#        [-4.00000000e-01],
#        [-3.00000000e-01],
#        [-2.00000000e-01],
#        [-1.00000000e-01],
#        [ 2.66453526e-15],
#        [ 1.00000000e-01],
#        [ 2.00000000e-01],
#        [ 3.00000000e-01],
#        [ 4.00000000e-01],
#        [ 5.00000000e-01],
#        [ 6.00000000e-01],
#        [ 7.00000000e-01],
#        [ 8.00000000e-01],
#        [ 9.00000000e-01],
#        [ 1.00000000e+00],
#        [ 1.10000000e+00],
#        [ 1.20000000e+00],
#        [ 1.30000000e+00],
#        [ 1.40000000e+00],
#        [ 1.50000000e+00],
#        [ 1.60000000e+00],
#        [ 1.70000000e+00],
#        [ 1.80000000e+00],
#        [ 1.90000000e+00],
#        [ 2.00000000e+00],
#        [ 2.10000000e+00],
#        [ 2.20000000e+00],
#        [ 2.30000000e+00],
#        [ 2.40000000e+00],
#        [ 2.50000000e+00],
#        [ 2.60000000e+00],
#        [ 2.70000000e+00],
#        [ 2.80000000e+00],
#        [ 2.90000000e+00]])

# %%
example_X
# Out:
# array([[ 1.00000000e+00, -3.00000000e+00,  9.00000000e+00],
#        [ 1.00000000e+00, -2.90000000e+00,  8.41000000e+00],
#        [ 1.00000000e+00, -2.80000000e+00,  7.84000000e+00],
#        [ 1.00000000e+00, -2.70000000e+00,  7.29000000e+00],
#        [ 1.00000000e+00, -2.60000000e+00,  6.76000000e+00],
#        [ 1.00000000e+00, -2.50000000e+00,  6.25000000e+00],
#        [ 1.00000000e+00, -2.40000000e+00,  5.76000000e+00],
#        [ 1.00000000e+00, -2.30000000e+00,  5.29000000e+00],
#        [ 1.00000000e+00, -2.20000000e+00,  4.84000000e+00],
#        [ 1.00000000e+00, -2.10000000e+00,  4.41000000e+00],
#        [ 1.00000000e+00, -2.00000000e+00,  4.00000000e+00],
#        [ 1.00000000e+00, -1.90000000e+00,  3.61000000e+00],
#        [ 1.00000000e+00, -1.80000000e+00,  3.24000000e+00],
#        [ 1.00000000e+00, -1.70000000e+00,  2.89000000e+00],
#        [ 1.00000000e+00, -1.60000000e+00,  2.56000000e+00],
#        [ 1.00000000e+00, -1.50000000e+00,  2.25000000e+00],
#        [ 1.00000000e+00, -1.40000000e+00,  1.96000000e+00],
#        [ 1.00000000e+00, -1.30000000e+00,  1.69000000e+00],
#        [ 1.00000000e+00, -1.20000000e+00,  1.44000000e+00],
#        [ 1.00000000e+00, -1.10000000e+00,  1.21000000e+00],
#        [ 1.00000000e+00, -1.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00, -9.00000000e-01,  8.10000000e-01],
#        [ 1.00000000e+00, -8.00000000e-01,  6.40000000e-01],
#        [ 1.00000000e+00, -7.00000000e-01,  4.90000000e-01],
#        [ 1.00000000e+00, -6.00000000e-01,  3.60000000e-01],
#        [ 1.00000000e+00, -5.00000000e-01,  2.50000000e-01],
#        [ 1.00000000e+00, -4.00000000e-01,  1.60000000e-01],
#        [ 1.00000000e+00, -3.00000000e-01,  9.00000000e-02],
#        [ 1.00000000e+00, -2.00000000e-01,  4.00000000e-02],
#        [ 1.00000000e+00, -1.00000000e-01,  1.00000000e-02],
#        [ 1.00000000e+00,  2.66453526e-15,  7.09974815e-30],
#        [ 1.00000000e+00,  1.00000000e-01,  1.00000000e-02],
#        [ 1.00000000e+00,  2.00000000e-01,  4.00000000e-02],
#        [ 1.00000000e+00,  3.00000000e-01,  9.00000000e-02],
#        [ 1.00000000e+00,  4.00000000e-01,  1.60000000e-01],
#        [ 1.00000000e+00,  5.00000000e-01,  2.50000000e-01],
#        [ 1.00000000e+00,  6.00000000e-01,  3.60000000e-01],
#        [ 1.00000000e+00,  7.00000000e-01,  4.90000000e-01],
#        [ 1.00000000e+00,  8.00000000e-01,  6.40000000e-01],
#        [ 1.00000000e+00,  9.00000000e-01,  8.10000000e-01],
#        [ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00,  1.10000000e+00,  1.21000000e+00],
#        [ 1.00000000e+00,  1.20000000e+00,  1.44000000e+00],
#        [ 1.00000000e+00,  1.30000000e+00,  1.69000000e+00],
#        [ 1.00000000e+00,  1.40000000e+00,  1.96000000e+00],
#        [ 1.00000000e+00,  1.50000000e+00,  2.25000000e+00],
#        [ 1.00000000e+00,  1.60000000e+00,  2.56000000e+00],
#        [ 1.00000000e+00,  1.70000000e+00,  2.89000000e+00],
#        [ 1.00000000e+00,  1.80000000e+00,  3.24000000e+00],
#        [ 1.00000000e+00,  1.90000000e+00,  3.61000000e+00],
#        [ 1.00000000e+00,  2.00000000e+00,  4.00000000e+00],
#        [ 1.00000000e+00,  2.10000000e+00,  4.41000000e+00],
#        [ 1.00000000e+00,  2.20000000e+00,  4.84000000e+00],
#        [ 1.00000000e+00,  2.30000000e+00,  5.29000000e+00],
#        [ 1.00000000e+00,  2.40000000e+00,  5.76000000e+00],
#        [ 1.00000000e+00,  2.50000000e+00,  6.25000000e+00],
#        [ 1.00000000e+00,  2.60000000e+00,  6.76000000e+00],
#        [ 1.00000000e+00,  2.70000000e+00,  7.29000000e+00],
#        [ 1.00000000e+00,  2.80000000e+00,  7.84000000e+00],
#        [ 1.00000000e+00,  2.90000000e+00,  8.41000000e+00]])

# %% [markdown]
# Next, we compute the vector $\hat{y}=\phi(x) {\bf{\theta}}$ by multiplying the matrices $\phi(x)$ and ${\bf{\theta}}$. ${\bf{\theta}}$ is a weight vector that determines the value of the bias and the scale of the polynomial transformations. We will manually adjust these values to try to get a good fit using Binary Sign Classification model. The plus side of using ${\bf{\theta}}$ is that we can drop unwanted terms from prediction $h_i=sign(\hat{y}_i)$. For example we will implement computing the array of scores $\hat{y}$ as
# $$
# \begin{align}
# \hat{y}=\phi(x) {\bf{\theta}}= \begin{bmatrix}
#     1&x_{1} & x_{1}^2\\
#     1&x_{2}& x_{2}^2\\
#     \vdots & \vdots & \vdots \\
#     1&x_{n}& x_{n}^2
# \end{bmatrix}
# \begin{bmatrix}
#     0\\
#     0\\
#     1
# \end{bmatrix}=\begin{bmatrix}
#      x_{1}^2\\
#      x_{2}^2\\
#     \vdots\\
#      x_{n}^2
# \end{bmatrix}
# \end{align}
# $$

# %%
# We compute y_hat
theta = np.array([0,0,1])
y_hat = np.matmul(example_X,theta)

# %% [markdown]
# Now we'll plot our data

# %%
plt.figure(figsize=(8,8))
plt.scatter(np.arange(-3,3,0.1).reshape(-1,1) ,y_hat, c=example_y)
plt.title('Plot of Polynomial Transformation of Example Dataset')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# We can see that if we simply move this new curve down, we classify most of the examples correctly using the Binary Sign classifier. We'll do so by adjusting ${\bf{\theta}}$ so that the second degree polynomial term is moved down slightly by calculating:
# $$
# \begin{align}
# \hat{y}=\phi(x) {\bf{\theta}}= \begin{bmatrix}
#     1&x_{1} & x_{1}^2\\
#     1&x_{2}& x_{2}^2\\
#     \vdots & \vdots & \vdots \\
#     1&x_{n}& x_{n}^2
# \end{bmatrix}
# \begin{bmatrix}
#     -0.9\\
#     0\\
#     1
# \end{bmatrix}=\begin{bmatrix}
#      x_{1}^2-0.9\\
#      x_{2}^2-0.9\\
#     \vdots\\
#      x_{n}^2
# -0.9\end{bmatrix}
# \end{align}
# $$

# %%
# Change the weight value
theta = np.array([-0.9,0,1])

# Compute y_hat
y_hat = np.matmul(example_X,theta)

# Plot
import matplotlib.patches as mpatches
plt.figure(figsize=(8,8))
arr1 = plt.scatter(np.arange(-3,3,0.1).reshape(-1,1) ,y_hat, c=example_y)
y_lim = plt.ylim()
x_lim = plt.xlim()
arr2 = plt.plot(x_lim, (0,0), 'k-', color = 'r')
plt.ylim(y_lim)
plt.xlim(x_lim)
plt.legend([arr1, arr2], ['u','v'])
red_patch = mpatches.Patch(color='red', label='Y-axis',linestyle ='-')
plt.legend(handles=[red_patch],loc='lower right', frameon=False)
plt.title('Plot of Polynomial Transformation of Example Dataset with y=0 decision boundary')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# We can now see that if we were to classify the datapoints by the sign of $y_i$ that most of the data points would be correctly classified as those below the y-axis would be classified as 0 while the rest would be classified as 1.

# %% [markdown]
# ### Second transformation example:
# In addition to implementing a polynomial transformation and moving it up or down, we can also move the transformation right or left using a simple yet tricky transformation. Recall that a function $f(x)$ can be moved right $q$ units by computing $f(x-q)$ or to the left by $q$ computing $f(x+q)$. We can also move the polynomial transform left or right in a similar fashion by letting $\phi_j(x)=(x-q)^j$. Now we want to implement a right transform by choosing $q = 2$, carrying out a polynomial transforms, and shifting polynomial transforms down by 0.9. So to begin, we first want to transform the example_dataset into:
#
# $$X =\begin{bmatrix}
#     1&(x_{1}-2) & (x_{1}-2)^2\\
#     1&(x_{2}-2)& (x_{2}-2)^2\\
#     \vdots & \vdots & \vdots \\
#     1&(x_{n}-2)& (x_{n}-2)^2
# \end{bmatrix}$$
# This should move our transformed value over to the right 2 units.

# %%
# First subtract 2 from each row in example_data
example_X = example_data-2

# Compute the 2nd degree polynomial transform
example_X = poly.fit_transform(example_X)

# Compute new y_hat with same theta as before
theta = np.array([-0.9,0,1])
y_hat = np.matmul(example_X,theta)

# Plot
import matplotlib.patches as mpatches
plt.figure(figsize=(8,8))
arr1 = plt.scatter(np.arange(-3,3,0.1).reshape(-1,1) ,y_hat, c=example_y)
y_lim = plt.ylim()
x_lim = plt.xlim()
arr2 = plt.plot(x_lim, (0,0), 'k-', color = 'r')
plt.ylim(y_lim)
plt.xlim(x_lim)
plt.legend([arr1, arr2], ['u','v'])
red_patch = mpatches.Patch(color='red', label='Y-axis',linestyle ='-')
plt.legend(handles=[red_patch],loc='lower right', frameon=False)
plt.title('Plot of Polynomial and Linear Transformation of Example Dataset with y=0 decision boundary')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# You can see that the parabola now begins at 2, rather than zero, and is shifted down.

# %% [markdown]
# ## Binary Sign Classification on dataset from part (i)

# %% [markdown]
# ### ii.a) How do you think a sign classification plus transformation model will perform on the Gaussian Quantile data?

# %% [markdown]
# #### Answer
# The sign classification and transformation model from the example essentially moved the middle values below the y-axis and from that if the logistic regression was calulated I assume that there will be be a higher accuracy. That is the same effect I assume that the Gaussian Quantile data will go through.

# %% [markdown]
# ### ii.b) Implementation
# Now, you will implement a Binary Sign Classification model to transform the linear data from part (i) as well as implement the helper functions to compute $\hat{y}$, the class prediction, and the model accuracy. Then you will use the methods outlined above to transform the data into a new form for classification. For this example, we will just run our model on all of the data x and y.

# %%
# Implement these helper functions

def generate_h(y):
    """
    Generates the class prediction h[i]=1 if y[i]>0 or h[i]=0 if y[i]<0
    args:
        y: a numpy array of y values
    return: a (500,1) array of 1 and 0s indicating class prediction
    """
    h = np.array([1 if yVal>0 else 0 for yVal in y]).reshape(-1,1) # YOUR CODE HERE h[i]=1 if y[i]>0 or h[i]=0 if y[i]<0
    
    return h


def compute_accuracy(y, h): 
    """
    computes the accuracy of the model. (h-y)/len(y)
    args:
        y: true class label
        h: predicted labels
    return: the accuracy.
    """
    accuracy = (np.sum(y==h))/len(y)# YOUR CODE HERE
    # print(len(y))
    return accuracy*100

# %%
# Impelement your data transformation using scikit learn polynomial
polynomial_degree = 2 # CHOOSE VALUE choose a degree for polynomial transformation
q = -3# CHOOSE VALUE choose a value for horizontal shift
poly = PolynomialFeatures(polynomial_degree)
X_tf = X.reshape(-1,1) # Don't change
X_tf = poly.fit_transform(X_tf-q)

# %%
# Compute y_hat
theta = np.array([-1.46,0,1]) # ADJUST THESE WEIGHTS. The length of w needs to be the same as the degree of polynomial+1,
# Either delete a poly-term or scale it, shift the transformed values up or down

y_hat = np.matmul(X_tf,theta) # Compute y_hat's

# Run sign model
h = generate_h(y_hat)
accuracy = compute_accuracy(y,h)
print(f"accuracy= {accuracy}%")
# Out:
# accuracy= 90.8%

# %% [markdown]
# ### Plotting data against y=0
# The plotting function below may be helpful for visualizing the data against the decision boundary.

# %%
# Plot
import matplotlib.patches as mpatches
plt.figure(figsize=(8,8))
arr1 = plt.scatter(X ,y_hat, c=y)
y_lim = plt.ylim()
x_lim = plt.xlim()
arr2 = plt.plot(x_lim, (0,0), 'k-', color = 'r')
plt.ylim(y_lim)
plt.xlim(x_lim)
red_patch = mpatches.Patch(color='red', label='Y-axis',linestyle ='-')
plt.legend(handles=[red_patch],loc='lower right', frameon=False)
plt.title('Plot of Gaussian Quantile Dataset with y=0 decision boundary')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### ii.c) How did we do?
#
# Please comment on the performance of the model you created on classifying the dataset. What transformation parameters did you use? What was your ${\bf{\theta}}$?

# %% [markdown]
# #### Answer
# At first I was confused as to what to start editing but as I fiddled with the values I ended up with a transformation parameter q with a value of -3. The resulting $\theta$ that i used is the following array:
# $$
# \left[-1.46,0,1 \right]
# $$

# %% [markdown]
# ##iii) Artificial Neural Network
# Next, we will use tensorflow to create an artificial neural network to classify the Gaussian Quantile dataset.

# %% [markdown]
# ### iii.a) Build a Neural Network to feed in the Gaussian Quantile data
#
# Below, define a neural network with the following layers:
# <ul>
# <li>Input Layer</li>
# <li>Dense Layer with 15 neurons, choose whatever activation you think is suitable</li>
# <li>Dense Layer with 5 neurons, choose whatever activation you think is suitable</li>
# <li>Dense Layer with 1 neuron, choose whatever activation you think is suitable</li>
# <li> Dense layer with 1 neuron for classification (what activation do we need to use?)</li>
# </ul>
#
# Then, run model.summary(), compile, then fit the model

# %%
from tensorflow.keras.layers import Input, Dense # Only use these layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import * 

# BUILD NETWORK HERE
input_layer = Input(shape=(1))
x=Dense(units=15,activation='tanh')(input_layer)
x=Dense(units=5,activation='tanh',)(x)
x=Dense(units=1,activation='tanh')(x)
x=Dense(units=1,activation='sigmoid')(x)
model = Model(input_layer,(x))

# %%
# Show a summary of your model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# dense (Dense)                (None, 15)                30
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 80
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 118
# Trainable params: 118
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile your model with the chosen optimizer, binary cross entropy for the loss, and accuracy as the metric
optimizer = Adam()
model.compile(optimizer=optimizer,loss='bce',metrics=['accuracy'])

# %%
# Call fit on your model passing in the X, y data above, train for 100 epochs
hist = model.fit(X, y, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.6826 - accuracy: 0.5800 - val_loss: 0.6928 - val_accuracy: 0.5600
# Epoch 2/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6651 - accuracy: 0.5900 - val_loss: 0.6724 - val_accuracy: 0.5800
# Epoch 3/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6520 - accuracy: 0.6250 - val_loss: 0.6569 - val_accuracy: 0.6100
# Epoch 4/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6426 - accuracy: 0.6700 - val_loss: 0.6469 - val_accuracy: 0.6600
# Epoch 5/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6363 - accuracy: 0.6850 - val_loss: 0.6385 - val_accuracy: 0.6800
# Epoch 6/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6306 - accuracy: 0.7025 - val_loss: 0.6316 - val_accuracy: 0.6900
# Epoch 7/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6252 - accuracy: 0.7050 - val_loss: 0.6251 - val_accuracy: 0.7100
# Epoch 8/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6195 - accuracy: 0.7100 - val_loss: 0.6185 - val_accuracy: 0.7200
# Epoch 9/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6137 - accuracy: 0.7100 - val_loss: 0.6126 - val_accuracy: 0.7200
# Epoch 10/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6083 - accuracy: 0.7100 - val_loss: 0.6075 - val_accuracy: 0.7200
# Epoch 11/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6032 - accuracy: 0.7075 - val_loss: 0.6010 - val_accuracy: 0.7200
# Epoch 12/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5969 - accuracy: 0.7275 - val_loss: 0.5939 - val_accuracy: 0.7200
# Epoch 13/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5909 - accuracy: 0.7275 - val_loss: 0.5867 - val_accuracy: 0.7300
# Epoch 14/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5849 - accuracy: 0.7325 - val_loss: 0.5803 - val_accuracy: 0.7300
# Epoch 15/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5787 - accuracy: 0.7325 - val_loss: 0.5731 - val_accuracy: 0.7600
# Epoch 16/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5717 - accuracy: 0.7350 - val_loss: 0.5670 - val_accuracy: 0.7700
# Epoch 17/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5666 - accuracy: 0.7650 - val_loss: 0.5588 - val_accuracy: 0.7900
# Epoch 18/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5587 - accuracy: 0.7725 - val_loss: 0.5531 - val_accuracy: 0.7900
# Epoch 19/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5526 - accuracy: 0.7825 - val_loss: 0.5460 - val_accuracy: 0.7900
# Epoch 20/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5451 - accuracy: 0.7900 - val_loss: 0.5381 - val_accuracy: 0.8300
# Epoch 21/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5384 - accuracy: 0.8050 - val_loss: 0.5325 - val_accuracy: 0.7900
# Epoch 22/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5337 - accuracy: 0.7650 - val_loss: 0.5264 - val_accuracy: 0.8000
# Epoch 23/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5292 - accuracy: 0.8525 - val_loss: 0.5182 - val_accuracy: 0.8700
# Epoch 24/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5186 - accuracy: 0.8350 - val_loss: 0.5142 - val_accuracy: 0.8400
# Epoch 25/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5135 - accuracy: 0.8075 - val_loss: 0.5074 - val_accuracy: 0.8300
# Epoch 26/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.8250 - val_loss: 0.4993 - val_accuracy: 0.8500
# Epoch 27/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4998 - accuracy: 0.8750 - val_loss: 0.4924 - val_accuracy: 0.8800
# Epoch 28/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4937 - accuracy: 0.8250 - val_loss: 0.4878 - val_accuracy: 0.8500
# Epoch 29/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4863 - accuracy: 0.8400 - val_loss: 0.4801 - val_accuracy: 0.8800
# Epoch 30/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4795 - accuracy: 0.8625 - val_loss: 0.4740 - val_accuracy: 0.8700
# Epoch 31/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4738 - accuracy: 0.8450 - val_loss: 0.4684 - val_accuracy: 0.8700
# Epoch 32/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4693 - accuracy: 0.8650 - val_loss: 0.4615 - val_accuracy: 0.8800
# Epoch 33/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4626 - accuracy: 0.8450 - val_loss: 0.4582 - val_accuracy: 0.8500
# Epoch 34/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4550 - accuracy: 0.8700 - val_loss: 0.4499 - val_accuracy: 0.9000
# Epoch 35/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4491 - accuracy: 0.8875 - val_loss: 0.4456 - val_accuracy: 0.8800
# Epoch 36/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4447 - accuracy: 0.8525 - val_loss: 0.4407 - val_accuracy: 0.8800
# Epoch 37/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4375 - accuracy: 0.8800 - val_loss: 0.4338 - val_accuracy: 0.9100
# Epoch 38/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4319 - accuracy: 0.8825 - val_loss: 0.4292 - val_accuracy: 0.8800
# Epoch 39/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.8825 - val_loss: 0.4237 - val_accuracy: 0.9000
# Epoch 40/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4200 - accuracy: 0.8825 - val_loss: 0.4195 - val_accuracy: 0.8800
# Epoch 41/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4158 - accuracy: 0.8800 - val_loss: 0.4136 - val_accuracy: 0.9000
# Epoch 42/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4097 - accuracy: 0.8900 - val_loss: 0.4100 - val_accuracy: 0.8900
# Epoch 43/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4048 - accuracy: 0.8875 - val_loss: 0.4057 - val_accuracy: 0.8900
# Epoch 44/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4013 - accuracy: 0.8825 - val_loss: 0.4016 - val_accuracy: 0.8900
# Epoch 45/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3947 - accuracy: 0.8875 - val_loss: 0.3967 - val_accuracy: 0.9000
# Epoch 46/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3906 - accuracy: 0.8825 - val_loss: 0.3931 - val_accuracy: 0.9000
# Epoch 47/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3857 - accuracy: 0.8850 - val_loss: 0.3895 - val_accuracy: 0.9000
# Epoch 48/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3812 - accuracy: 0.8900 - val_loss: 0.3857 - val_accuracy: 0.9000
# Epoch 49/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3773 - accuracy: 0.8950 - val_loss: 0.3821 - val_accuracy: 0.8900
# Epoch 50/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3732 - accuracy: 0.8825 - val_loss: 0.3781 - val_accuracy: 0.8900
# Epoch 51/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3699 - accuracy: 0.8900 - val_loss: 0.3752 - val_accuracy: 0.8900
# Epoch 52/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3657 - accuracy: 0.9000 - val_loss: 0.3717 - val_accuracy: 0.8900
# Epoch 53/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3626 - accuracy: 0.8825 - val_loss: 0.3689 - val_accuracy: 0.8900
# Epoch 54/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3608 - accuracy: 0.8950 - val_loss: 0.3659 - val_accuracy: 0.9000
# Epoch 55/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3555 - accuracy: 0.8900 - val_loss: 0.3625 - val_accuracy: 0.9000
# Epoch 56/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3533 - accuracy: 0.8950 - val_loss: 0.3601 - val_accuracy: 0.9000
# Epoch 57/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3480 - accuracy: 0.8950 - val_loss: 0.3577 - val_accuracy: 0.8900
# Epoch 58/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3445 - accuracy: 0.8950 - val_loss: 0.3554 - val_accuracy: 0.8900
# Epoch 59/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3417 - accuracy: 0.9000 - val_loss: 0.3531 - val_accuracy: 0.8900
# Epoch 60/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3387 - accuracy: 0.9000 - val_loss: 0.3500 - val_accuracy: 0.8800
# Epoch 61/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3367 - accuracy: 0.8950 - val_loss: 0.3478 - val_accuracy: 0.8900
# Epoch 62/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3350 - accuracy: 0.8975 - val_loss: 0.3448 - val_accuracy: 0.8800
# Epoch 63/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3307 - accuracy: 0.8975 - val_loss: 0.3441 - val_accuracy: 0.8900
# Epoch 64/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3302 - accuracy: 0.8900 - val_loss: 0.3412 - val_accuracy: 0.8900
# Epoch 65/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3256 - accuracy: 0.9000 - val_loss: 0.3427 - val_accuracy: 0.8600
# Epoch 66/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3246 - accuracy: 0.9000 - val_loss: 0.3373 - val_accuracy: 0.8900
# Epoch 67/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3199 - accuracy: 0.9025 - val_loss: 0.3363 - val_accuracy: 0.8700
# Epoch 68/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3181 - accuracy: 0.9000 - val_loss: 0.3339 - val_accuracy: 0.8700
# Epoch 69/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3163 - accuracy: 0.9025 - val_loss: 0.3301 - val_accuracy: 0.8800
# Epoch 70/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3134 - accuracy: 0.9000 - val_loss: 0.3300 - val_accuracy: 0.8900
# Epoch 71/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3112 - accuracy: 0.8950 - val_loss: 0.3284 - val_accuracy: 0.8700
# Epoch 72/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3088 - accuracy: 0.9025 - val_loss: 0.3274 - val_accuracy: 0.8800
# Epoch 73/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3071 - accuracy: 0.8975 - val_loss: 0.3240 - val_accuracy: 0.8700
# Epoch 74/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3049 - accuracy: 0.9025 - val_loss: 0.3236 - val_accuracy: 0.8800
# Epoch 75/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3043 - accuracy: 0.9000 - val_loss: 0.3215 - val_accuracy: 0.8800
# Epoch 76/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3019 - accuracy: 0.9025 - val_loss: 0.3197 - val_accuracy: 0.8700
# Epoch 77/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3004 - accuracy: 0.9000 - val_loss: 0.3201 - val_accuracy: 0.8700
# Epoch 78/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2991 - accuracy: 0.9000 - val_loss: 0.3193 - val_accuracy: 0.8700
# Epoch 79/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2986 - accuracy: 0.8975 - val_loss: 0.3163 - val_accuracy: 0.8900
# Epoch 80/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2967 - accuracy: 0.9000 - val_loss: 0.3150 - val_accuracy: 0.8700
# Epoch 81/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2933 - accuracy: 0.9050 - val_loss: 0.3133 - val_accuracy: 0.8700
# Epoch 82/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2930 - accuracy: 0.9000 - val_loss: 0.3138 - val_accuracy: 0.8700
# Epoch 83/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2907 - accuracy: 0.9000 - val_loss: 0.3116 - val_accuracy: 0.8800
# Epoch 84/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2891 - accuracy: 0.9000 - val_loss: 0.3121 - val_accuracy: 0.8600
# Epoch 85/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2874 - accuracy: 0.9025 - val_loss: 0.3102 - val_accuracy: 0.8700
# Epoch 86/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2857 - accuracy: 0.9000 - val_loss: 0.3094 - val_accuracy: 0.8700
# Epoch 87/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2851 - accuracy: 0.8975 - val_loss: 0.3074 - val_accuracy: 0.8700
# Epoch 88/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2858 - accuracy: 0.9125 - val_loss: 0.3070 - val_accuracy: 0.8700
# Epoch 89/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2860 - accuracy: 0.8950 - val_loss: 0.3052 - val_accuracy: 0.8800
# Epoch 90/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2825 - accuracy: 0.9050 - val_loss: 0.3044 - val_accuracy: 0.8700
# Epoch 91/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2794 - accuracy: 0.9000 - val_loss: 0.3043 - val_accuracy: 0.8700
# Epoch 92/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2813 - accuracy: 0.9000 - val_loss: 0.3049 - val_accuracy: 0.8600
# Epoch 93/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2780 - accuracy: 0.9025 - val_loss: 0.3020 - val_accuracy: 0.8700
# Epoch 94/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2770 - accuracy: 0.9000 - val_loss: 0.3010 - val_accuracy: 0.8700
# Epoch 95/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2756 - accuracy: 0.9025 - val_loss: 0.3022 - val_accuracy: 0.8700
# Epoch 96/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2755 - accuracy: 0.9000 - val_loss: 0.3017 - val_accuracy: 0.8600
# Epoch 97/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2728 - accuracy: 0.9000 - val_loss: 0.3010 - val_accuracy: 0.8700
# Epoch 98/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2732 - accuracy: 0.9025 - val_loss: 0.2994 - val_accuracy: 0.8600
# Epoch 99/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2741 - accuracy: 0.9050 - val_loss: 0.2951 - val_accuracy: 0.8700
# Epoch 100/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2710 - accuracy: 0.9000 - val_loss: 0.2947 - val_accuracy: 0.8700

# %%
def plot_losses(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'])
    plt.show()
def plot_accuracies(hist):
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'])
    plt.show()

# %%
from mlxtend.plotting import plot_decision_regions
# plot your losses and accuracies
plot_losses(hist)
plot_accuracies(hist)
plt.figure(figsize=(5,5))
# print(X.shape)
plt.scatter(X[:, 0], y)
plot_decision_regions(X, y[:,0], clf=model, legend=2)
plt.show()

# %% [markdown]
# ###iii.a) How did the model perform.
# How did your neural network preform? What hyperparameters and optimizer did you choose? Was the model able to outperform Logistic Regression? Outperform Binary Sign Classification? If it did, why do you think your neural network beat these other models?

# %% [markdown]
# #### Answer
# The neural-network based model performed better than simple logistic regression by a pretty big factor and Binary Sign Classification performed similar. The reason I believe that the Bin Sign Classification did better is because of the polynomial transformation spreading out the data points a bit allowing for the points that are tangled to untangle and be better classified. The simple logistic regression couldn't deal with making 2 decision boundaries and to solve that we added a polynomial transformation and set it so that the dataset seperated the classes on either side of the Y-axis. That got us a bit more accurate but not enough since some nodes that were one class were on the other side of the Y-axis from where it should be in the other class.

# %% [markdown]
# #2) Neural Network Classification
# Next, we move on to using an artificial Neural Network for a task that is a bit harder. We will see if we can train our model to determine if patients with suffering from heart disease died during follow up treatment. The dataset has 299 samples with 12 features each and a target class:
# <ul>
# <li>age: age of the patient (years)</li>
# <li>anaemia: decrease of red blood cells or hemoglobin (boolean)</li>
# <li>high blood pressure: if the patient has hypertension (boolean)</li>
# <li>creatinine phosphokinase (CPK): level of the CPK enzyme in the blood (mcg/L)</li>
# <li> diabetes: if the patient has diabetes (boolean)</li>
# <li> ejection fraction: percentage of blood leaving the heart at each contraction (percentage)</li>
# <li> platelets: platelets in the blood (kiloplatelets/mL)</li>
# <li> sex: woman or man (binary)</li>
# <li> serum creatinine: level of serum creatinine in the blood (mg/dL)</li>
# <li> serum sodium: level of serum sodium in the blood (mEq/L)</li>
# <li> smoking: if the patient smokes or not (boolean)</li>
# <li> time: follow-up period (days)</li>
# <li> [target] death event: if the patient deceased during the follow-up period (boolean)</li>
# </ul>

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00519/heart_failure_clinical_records_dataset.csv
# Out:
# --2020-07-12 20:11:09--  https://archive.ics.uci.edu/ml/machine-learning-databases/00519/heart_failure_clinical_records_dataset.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12239 (12K) [application/x-httpd-php]
# Saving to: ‘heart_failure_clinical_records_dataset.csv.14’
#
# heart_failure_clini 100%[===================>]  11.95K  --.-KB/s    in 0s
#
# 2020-07-12 20:11:09 (116 MB/s) - ‘heart_failure_clinical_records_dataset.csv.14’ saved [12239/12239]

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
# Read in the data
nn_dataframe = pd.read_csv('heart_failure_clinical_records_dataset.csv',sep=',')
nn_dataframe.dropna(inplace=True)

# %%
# Check data
nn_dataframe.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %% [markdown]
# Split Data into X and y. Then scale the X data for model training

# %%
X = nn_dataframe.iloc[:, 0:12]
y = nn_dataframe.iloc[:,12]

# %%
# Check X data
X.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  sex  smoking  time
# 0  75.0        0                       582  ...    1        0     4
# 1  55.0        0                      7861  ...    1        0     6
# 2  65.0        0                       146  ...    1        1     7
# 3  50.0        1                       111  ...    1        0     7
# 4  65.0        1                       160  ...    0        0     8
#
# [5 rows x 12 columns]

# %% [markdown]
# ###2.a) Use MinMaxScaler() to preprocess the dataset.
# This is similar to standardization but will transform all the feature values to between 0 and 1. \\
# **Hint: read information on MinMaxScaler (and other preprocessing transforms here):https://scikit-learn.org/stable/modules/preprocessing.html#normalization

# %%
from sklearn import preprocessing

X = X.values # Returns a numpy array
print(X.shape)
min_max_scaler = preprocessing.MinMaxScaler()# YOUR CODE HERE define the MinMaxScaler object
X = min_max_scaler.fit_transform(X)# YOUR CODE HERE fit the MinMaxScaler

# Create numpy array of labels
y = y.values
# Out:
# (299, 12)

# %% [markdown]
# ###2.b) Implement an Artificial Neural network
# Make a neural network to your liking. Define the input layer. Add Layers, specify the number of neurons in each layer, and the activation. and define the out layer.

# %%
# BUILD NETWORK HERE
input_layer = Input(shape=(12))
x=Dense(units=25,activation='tanh')(input_layer)
x=Dense(units=15,activation='tanh',)(x)
x=Dense(units=7,activation='tanh')(x)
x=Dense(units=1,activation='tanh')(x)
x=Dense(units=1,activation='sigmoid')(x)
model = Model(input_layer,(x))

# %%
# Show a summary of your model
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 12)]              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 25)                325
# _________________________________________________________________
# dense_5 (Dense)              (None, 15)                390
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 112
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 8
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 837
# Trainable params: 837
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile your model with the chosen optimizer, binary cross entropy for the loss, and accuracy as the metric
optimizer = Adam()
model.compile(optimizer=optimizer,loss='bce',metrics=['accuracy'])

# %%
# Call fit on your model passing in the X, y data above, train for 100 epochs
hist = model.fit(X, y, epochs=1000, validation_split=0.2)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7087 - accuracy: 0.5230 - val_loss: 0.5303 - val_accuracy: 0.8167
# Epoch 2/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6731 - accuracy: 0.6192 - val_loss: 0.5163 - val_accuracy: 0.9000
# Epoch 3/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6575 - accuracy: 0.6234 - val_loss: 0.5277 - val_accuracy: 0.9167
# Epoch 4/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6460 - accuracy: 0.6360 - val_loss: 0.4746 - val_accuracy: 0.9500
# Epoch 5/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6290 - accuracy: 0.6485 - val_loss: 0.4541 - val_accuracy: 0.9500
# Epoch 6/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6182 - accuracy: 0.6527 - val_loss: 0.4454 - val_accuracy: 0.9500
# Epoch 7/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6073 - accuracy: 0.6820 - val_loss: 0.4220 - val_accuracy: 0.9500
# Epoch 8/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5969 - accuracy: 0.7113 - val_loss: 0.3883 - val_accuracy: 0.9500
# Epoch 9/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5865 - accuracy: 0.7155 - val_loss: 0.3756 - val_accuracy: 0.9500
# Epoch 10/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5763 - accuracy: 0.7280 - val_loss: 0.3619 - val_accuracy: 0.9500
# Epoch 11/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5662 - accuracy: 0.7490 - val_loss: 0.3474 - val_accuracy: 0.9500
# Epoch 12/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5573 - accuracy: 0.7490 - val_loss: 0.3339 - val_accuracy: 0.9500
# Epoch 13/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5484 - accuracy: 0.7573 - val_loss: 0.3260 - val_accuracy: 0.9500
# Epoch 14/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5392 - accuracy: 0.7782 - val_loss: 0.3147 - val_accuracy: 0.9500
# Epoch 15/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5309 - accuracy: 0.7782 - val_loss: 0.3028 - val_accuracy: 0.9500
# Epoch 16/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5226 - accuracy: 0.7992 - val_loss: 0.2987 - val_accuracy: 0.9500
# Epoch 17/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5140 - accuracy: 0.8033 - val_loss: 0.2913 - val_accuracy: 0.9500
# Epoch 18/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5077 - accuracy: 0.8075 - val_loss: 0.2839 - val_accuracy: 0.9500
# Epoch 19/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5014 - accuracy: 0.8117 - val_loss: 0.2772 - val_accuracy: 0.9500
# Epoch 20/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4952 - accuracy: 0.8075 - val_loss: 0.2762 - val_accuracy: 0.9500
# Epoch 21/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4910 - accuracy: 0.8075 - val_loss: 0.2730 - val_accuracy: 0.9500
# Epoch 22/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4895 - accuracy: 0.8033 - val_loss: 0.2651 - val_accuracy: 0.9500
# Epoch 23/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4802 - accuracy: 0.8159 - val_loss: 0.2646 - val_accuracy: 0.9500
# Epoch 24/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4766 - accuracy: 0.8159 - val_loss: 0.2617 - val_accuracy: 0.9500
# Epoch 25/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4721 - accuracy: 0.8159 - val_loss: 0.2586 - val_accuracy: 0.9500
# Epoch 26/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4702 - accuracy: 0.8201 - val_loss: 0.2572 - val_accuracy: 0.9500
# Epoch 27/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4655 - accuracy: 0.8243 - val_loss: 0.2533 - val_accuracy: 0.9500
# Epoch 28/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4652 - accuracy: 0.8159 - val_loss: 0.2540 - val_accuracy: 0.9500
# Epoch 29/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4601 - accuracy: 0.8117 - val_loss: 0.2522 - val_accuracy: 0.9500
# Epoch 30/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4577 - accuracy: 0.8159 - val_loss: 0.2501 - val_accuracy: 0.9500
# Epoch 31/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4560 - accuracy: 0.8117 - val_loss: 0.2482 - val_accuracy: 0.9500
# Epoch 32/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4523 - accuracy: 0.8117 - val_loss: 0.2478 - val_accuracy: 0.9500
# Epoch 33/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4510 - accuracy: 0.8117 - val_loss: 0.2464 - val_accuracy: 0.9500
# Epoch 34/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4493 - accuracy: 0.8159 - val_loss: 0.2452 - val_accuracy: 0.9500
# Epoch 35/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4468 - accuracy: 0.8159 - val_loss: 0.2438 - val_accuracy: 0.9500
# Epoch 36/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4445 - accuracy: 0.8159 - val_loss: 0.2426 - val_accuracy: 0.9500
# Epoch 37/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4433 - accuracy: 0.8117 - val_loss: 0.2417 - val_accuracy: 0.9500
# Epoch 38/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4413 - accuracy: 0.8117 - val_loss: 0.2411 - val_accuracy: 0.9500
# Epoch 39/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4400 - accuracy: 0.8243 - val_loss: 0.2402 - val_accuracy: 0.9500
# Epoch 40/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4393 - accuracy: 0.8243 - val_loss: 0.2390 - val_accuracy: 0.9500
# Epoch 41/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4394 - accuracy: 0.8243 - val_loss: 0.2390 - val_accuracy: 0.9500
# Epoch 42/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4350 - accuracy: 0.8285 - val_loss: 0.2380 - val_accuracy: 0.9500
# Epoch 43/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4347 - accuracy: 0.8117 - val_loss: 0.2372 - val_accuracy: 0.9500
# Epoch 44/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4360 - accuracy: 0.8243 - val_loss: 0.2369 - val_accuracy: 0.9500
# Epoch 45/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4328 - accuracy: 0.8243 - val_loss: 0.2359 - val_accuracy: 0.9500
# Epoch 46/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4314 - accuracy: 0.8326 - val_loss: 0.2357 - val_accuracy: 0.9500
# Epoch 47/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4308 - accuracy: 0.8410 - val_loss: 0.2348 - val_accuracy: 0.9500
# Epoch 48/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4288 - accuracy: 0.8117 - val_loss: 0.2342 - val_accuracy: 0.9500
# Epoch 49/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4286 - accuracy: 0.8368 - val_loss: 0.2337 - val_accuracy: 0.9500
# Epoch 50/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4261 - accuracy: 0.8410 - val_loss: 0.2333 - val_accuracy: 0.9500
# Epoch 51/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4268 - accuracy: 0.8201 - val_loss: 0.2329 - val_accuracy: 0.9500
# Epoch 52/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4240 - accuracy: 0.8326 - val_loss: 0.2324 - val_accuracy: 0.9500
# Epoch 53/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4246 - accuracy: 0.8410 - val_loss: 0.2318 - val_accuracy: 0.9500
# Epoch 54/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4226 - accuracy: 0.8326 - val_loss: 0.2311 - val_accuracy: 0.9500
# Epoch 55/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4229 - accuracy: 0.8201 - val_loss: 0.2310 - val_accuracy: 0.9500
# Epoch 56/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4203 - accuracy: 0.8326 - val_loss: 0.2305 - val_accuracy: 0.9500
# Epoch 57/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4204 - accuracy: 0.8494 - val_loss: 0.2299 - val_accuracy: 0.9500
# Epoch 58/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4183 - accuracy: 0.8494 - val_loss: 0.2294 - val_accuracy: 0.9500
# Epoch 59/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4188 - accuracy: 0.8410 - val_loss: 0.2291 - val_accuracy: 0.9500
# Epoch 60/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4178 - accuracy: 0.8452 - val_loss: 0.2286 - val_accuracy: 0.9500
# Epoch 61/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4185 - accuracy: 0.8243 - val_loss: 0.2282 - val_accuracy: 0.9500
# Epoch 62/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4180 - accuracy: 0.8410 - val_loss: 0.2278 - val_accuracy: 0.9500
# Epoch 63/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4149 - accuracy: 0.8452 - val_loss: 0.2275 - val_accuracy: 0.9500
# Epoch 64/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4134 - accuracy: 0.8326 - val_loss: 0.2271 - val_accuracy: 0.9500
# Epoch 65/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4264 - accuracy: 0.8243 - val_loss: 0.2268 - val_accuracy: 0.9500
# Epoch 66/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4172 - accuracy: 0.8410 - val_loss: 0.2265 - val_accuracy: 0.9500
# Epoch 67/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4116 - accuracy: 0.8452 - val_loss: 0.2261 - val_accuracy: 0.9500
# Epoch 68/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4153 - accuracy: 0.8494 - val_loss: 0.2258 - val_accuracy: 0.9500
# Epoch 69/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4106 - accuracy: 0.8410 - val_loss: 0.2255 - val_accuracy: 0.9500
# Epoch 70/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4128 - accuracy: 0.8410 - val_loss: 0.2252 - val_accuracy: 0.9500
# Epoch 71/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4108 - accuracy: 0.8368 - val_loss: 0.2249 - val_accuracy: 0.9500
# Epoch 72/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4082 - accuracy: 0.8410 - val_loss: 0.2247 - val_accuracy: 0.9500
# Epoch 73/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4119 - accuracy: 0.8368 - val_loss: 0.2244 - val_accuracy: 0.9500
# Epoch 74/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4078 - accuracy: 0.8452 - val_loss: 0.2239 - val_accuracy: 0.9500
# Epoch 75/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4081 - accuracy: 0.8494 - val_loss: 0.2237 - val_accuracy: 0.9500
# Epoch 76/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4080 - accuracy: 0.8368 - val_loss: 0.2236 - val_accuracy: 0.9500
# Epoch 77/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4070 - accuracy: 0.8452 - val_loss: 0.2232 - val_accuracy: 0.9500
# Epoch 78/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4052 - accuracy: 0.8452 - val_loss: 0.2231 - val_accuracy: 0.9500
# Epoch 79/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4033 - accuracy: 0.8452 - val_loss: 0.2229 - val_accuracy: 0.9500
# Epoch 80/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4053 - accuracy: 0.8410 - val_loss: 0.2226 - val_accuracy: 0.9500
# Epoch 81/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4038 - accuracy: 0.8452 - val_loss: 0.2222 - val_accuracy: 0.9500
# Epoch 82/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4024 - accuracy: 0.8494 - val_loss: 0.2218 - val_accuracy: 0.9500
# Epoch 83/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4049 - accuracy: 0.8410 - val_loss: 0.2217 - val_accuracy: 0.9500
# Epoch 84/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4028 - accuracy: 0.8410 - val_loss: 0.2214 - val_accuracy: 0.9500
# Epoch 85/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4012 - accuracy: 0.8368 - val_loss: 0.2214 - val_accuracy: 0.9500
# Epoch 86/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3997 - accuracy: 0.8452 - val_loss: 0.2211 - val_accuracy: 0.9500
# Epoch 87/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3993 - accuracy: 0.8452 - val_loss: 0.2208 - val_accuracy: 0.9500
# Epoch 88/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3985 - accuracy: 0.8452 - val_loss: 0.2207 - val_accuracy: 0.9500
# Epoch 89/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3993 - accuracy: 0.8536 - val_loss: 0.2204 - val_accuracy: 0.9500
# Epoch 90/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4004 - accuracy: 0.8452 - val_loss: 0.2204 - val_accuracy: 0.9500
# Epoch 91/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3962 - accuracy: 0.8494 - val_loss: 0.2200 - val_accuracy: 0.9500
# Epoch 92/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3977 - accuracy: 0.8494 - val_loss: 0.2197 - val_accuracy: 0.9500
# Epoch 93/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3969 - accuracy: 0.8577 - val_loss: 0.2195 - val_accuracy: 0.9500
# Epoch 94/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3955 - accuracy: 0.8577 - val_loss: 0.2194 - val_accuracy: 0.9500
# Epoch 95/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3948 - accuracy: 0.8536 - val_loss: 0.2192 - val_accuracy: 0.9500
# Epoch 96/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3956 - accuracy: 0.8494 - val_loss: 0.2191 - val_accuracy: 0.9500
# Epoch 97/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3957 - accuracy: 0.8452 - val_loss: 0.2189 - val_accuracy: 0.9500
# Epoch 98/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3933 - accuracy: 0.8577 - val_loss: 0.2186 - val_accuracy: 0.9500
# Epoch 99/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3945 - accuracy: 0.8494 - val_loss: 0.2187 - val_accuracy: 0.9500
# Epoch 100/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3915 - accuracy: 0.8536 - val_loss: 0.2185 - val_accuracy: 0.9500
# Epoch 101/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3928 - accuracy: 0.8494 - val_loss: 0.2184 - val_accuracy: 0.9500
# Epoch 102/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3901 - accuracy: 0.8494 - val_loss: 0.2182 - val_accuracy: 0.9500
# Epoch 103/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3920 - accuracy: 0.8494 - val_loss: 0.2178 - val_accuracy: 0.9500
# Epoch 104/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3921 - accuracy: 0.8577 - val_loss: 0.2177 - val_accuracy: 0.9500
# Epoch 105/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4102 - accuracy: 0.8368 - val_loss: 0.2180 - val_accuracy: 0.9500
# Epoch 106/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3830 - accuracy: 0.8619 - val_loss: 0.2170 - val_accuracy: 0.9500
# Epoch 107/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4061 - accuracy: 0.8494 - val_loss: 0.2175 - val_accuracy: 0.9500
# Epoch 108/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3942 - accuracy: 0.8326 - val_loss: 0.2178 - val_accuracy: 0.9500
# Epoch 109/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3893 - accuracy: 0.8494 - val_loss: 0.2171 - val_accuracy: 0.9500
# Epoch 110/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3875 - accuracy: 0.8536 - val_loss: 0.2167 - val_accuracy: 0.9500
# Epoch 111/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3883 - accuracy: 0.8494 - val_loss: 0.2167 - val_accuracy: 0.9500
# Epoch 112/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3861 - accuracy: 0.8577 - val_loss: 0.2167 - val_accuracy: 0.9500
# Epoch 113/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3861 - accuracy: 0.8536 - val_loss: 0.2166 - val_accuracy: 0.9500
# Epoch 114/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3880 - accuracy: 0.8536 - val_loss: 0.2166 - val_accuracy: 0.9500
# Epoch 115/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3848 - accuracy: 0.8494 - val_loss: 0.2163 - val_accuracy: 0.9500
# Epoch 116/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3857 - accuracy: 0.8577 - val_loss: 0.2161 - val_accuracy: 0.9500
# Epoch 117/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3826 - accuracy: 0.8619 - val_loss: 0.2162 - val_accuracy: 0.9500
# Epoch 118/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3886 - accuracy: 0.8577 - val_loss: 0.2159 - val_accuracy: 0.9500
# Epoch 119/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3971 - accuracy: 0.8494 - val_loss: 0.2152 - val_accuracy: 0.9500
# Epoch 120/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3829 - accuracy: 0.8661 - val_loss: 0.2156 - val_accuracy: 0.9500
# Epoch 121/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3884 - accuracy: 0.8452 - val_loss: 0.2153 - val_accuracy: 0.9500
# Epoch 122/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3849 - accuracy: 0.8703 - val_loss: 0.2146 - val_accuracy: 0.9500
# Epoch 123/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3812 - accuracy: 0.8661 - val_loss: 0.2150 - val_accuracy: 0.9500
# Epoch 124/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3833 - accuracy: 0.8536 - val_loss: 0.2151 - val_accuracy: 0.9500
# Epoch 125/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3829 - accuracy: 0.8619 - val_loss: 0.2142 - val_accuracy: 0.9500
# Epoch 126/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3822 - accuracy: 0.8619 - val_loss: 0.2146 - val_accuracy: 0.9500
# Epoch 127/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3798 - accuracy: 0.8577 - val_loss: 0.2141 - val_accuracy: 0.9500
# Epoch 128/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3809 - accuracy: 0.8577 - val_loss: 0.2137 - val_accuracy: 0.9500
# Epoch 129/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3786 - accuracy: 0.8577 - val_loss: 0.2141 - val_accuracy: 0.9500
# Epoch 130/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3772 - accuracy: 0.8703 - val_loss: 0.2141 - val_accuracy: 0.9500
# Epoch 131/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3780 - accuracy: 0.8745 - val_loss: 0.2139 - val_accuracy: 0.9500
# Epoch 132/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3818 - accuracy: 0.8577 - val_loss: 0.2142 - val_accuracy: 0.9500
# Epoch 133/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3785 - accuracy: 0.8703 - val_loss: 0.2132 - val_accuracy: 0.9500
# Epoch 134/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3760 - accuracy: 0.8703 - val_loss: 0.2136 - val_accuracy: 0.9500
# Epoch 135/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3764 - accuracy: 0.8619 - val_loss: 0.2136 - val_accuracy: 0.9500
# Epoch 136/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3775 - accuracy: 0.8745 - val_loss: 0.2128 - val_accuracy: 0.9500
# Epoch 137/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3757 - accuracy: 0.8577 - val_loss: 0.2129 - val_accuracy: 0.9500
# Epoch 138/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3744 - accuracy: 0.8661 - val_loss: 0.2126 - val_accuracy: 0.9500
# Epoch 139/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3740 - accuracy: 0.8745 - val_loss: 0.2123 - val_accuracy: 0.9500
# Epoch 140/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3731 - accuracy: 0.8661 - val_loss: 0.2130 - val_accuracy: 0.9500
# Epoch 141/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3752 - accuracy: 0.8577 - val_loss: 0.2128 - val_accuracy: 0.9500
# Epoch 142/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3722 - accuracy: 0.8703 - val_loss: 0.2120 - val_accuracy: 0.9500
# Epoch 143/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3752 - accuracy: 0.8619 - val_loss: 0.2121 - val_accuracy: 0.9500
# Epoch 144/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3723 - accuracy: 0.8703 - val_loss: 0.2118 - val_accuracy: 0.9500
# Epoch 145/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3752 - accuracy: 0.8619 - val_loss: 0.2120 - val_accuracy: 0.9500
# Epoch 146/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3698 - accuracy: 0.8703 - val_loss: 0.2117 - val_accuracy: 0.9500
# Epoch 147/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3736 - accuracy: 0.8745 - val_loss: 0.2111 - val_accuracy: 0.9500
# Epoch 148/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3771 - accuracy: 0.8577 - val_loss: 0.2118 - val_accuracy: 0.9500
# Epoch 149/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3738 - accuracy: 0.8619 - val_loss: 0.2105 - val_accuracy: 0.9500
# Epoch 150/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3702 - accuracy: 0.8703 - val_loss: 0.2104 - val_accuracy: 0.9500
# Epoch 151/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3692 - accuracy: 0.8745 - val_loss: 0.2105 - val_accuracy: 0.9500
# Epoch 152/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3697 - accuracy: 0.8703 - val_loss: 0.2107 - val_accuracy: 0.9500
# Epoch 153/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3688 - accuracy: 0.8703 - val_loss: 0.2099 - val_accuracy: 0.9500
# Epoch 154/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3756 - accuracy: 0.8661 - val_loss: 0.2093 - val_accuracy: 0.9500
# Epoch 155/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3693 - accuracy: 0.8661 - val_loss: 0.2108 - val_accuracy: 0.9500
# Epoch 156/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3674 - accuracy: 0.8703 - val_loss: 0.2100 - val_accuracy: 0.9500
# Epoch 157/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3658 - accuracy: 0.8828 - val_loss: 0.2102 - val_accuracy: 0.9500
# Epoch 158/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3652 - accuracy: 0.8745 - val_loss: 0.2096 - val_accuracy: 0.9500
# Epoch 159/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8745 - val_loss: 0.2099 - val_accuracy: 0.9500
# Epoch 160/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3650 - accuracy: 0.8787 - val_loss: 0.2092 - val_accuracy: 0.9500
# Epoch 161/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3663 - accuracy: 0.8745 - val_loss: 0.2094 - val_accuracy: 0.9500
# Epoch 162/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3635 - accuracy: 0.8787 - val_loss: 0.2084 - val_accuracy: 0.9500
# Epoch 163/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3688 - accuracy: 0.8661 - val_loss: 0.2094 - val_accuracy: 0.9500
# Epoch 164/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3653 - accuracy: 0.8745 - val_loss: 0.2081 - val_accuracy: 0.9500
# Epoch 165/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3627 - accuracy: 0.8787 - val_loss: 0.2082 - val_accuracy: 0.9500
# Epoch 166/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3613 - accuracy: 0.8703 - val_loss: 0.2083 - val_accuracy: 0.9500
# Epoch 167/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3612 - accuracy: 0.8745 - val_loss: 0.2082 - val_accuracy: 0.9500
# Epoch 168/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3622 - accuracy: 0.8745 - val_loss: 0.2084 - val_accuracy: 0.9500
# Epoch 169/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3637 - accuracy: 0.8787 - val_loss: 0.2071 - val_accuracy: 0.9500
# Epoch 170/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3604 - accuracy: 0.8787 - val_loss: 0.2082 - val_accuracy: 0.9500
# Epoch 171/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3603 - accuracy: 0.8703 - val_loss: 0.2077 - val_accuracy: 0.9500
# Epoch 172/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3617 - accuracy: 0.8703 - val_loss: 0.2079 - val_accuracy: 0.9500
# Epoch 173/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3576 - accuracy: 0.8787 - val_loss: 0.2066 - val_accuracy: 0.9500
# Epoch 174/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3592 - accuracy: 0.8828 - val_loss: 0.2070 - val_accuracy: 0.9500
# Epoch 175/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3605 - accuracy: 0.8661 - val_loss: 0.2080 - val_accuracy: 0.9500
# Epoch 176/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3592 - accuracy: 0.8661 - val_loss: 0.2070 - val_accuracy: 0.9500
# Epoch 177/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3579 - accuracy: 0.8703 - val_loss: 0.2069 - val_accuracy: 0.9500
# Epoch 178/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3584 - accuracy: 0.8661 - val_loss: 0.2062 - val_accuracy: 0.9500
# Epoch 179/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3616 - accuracy: 0.8787 - val_loss: 0.2068 - val_accuracy: 0.9500
# Epoch 180/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3563 - accuracy: 0.8828 - val_loss: 0.2057 - val_accuracy: 0.9500
# Epoch 181/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3562 - accuracy: 0.8703 - val_loss: 0.2060 - val_accuracy: 0.9500
# Epoch 182/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3567 - accuracy: 0.8745 - val_loss: 0.2049 - val_accuracy: 0.9500
# Epoch 183/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3554 - accuracy: 0.8787 - val_loss: 0.2057 - val_accuracy: 0.9500
# Epoch 184/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3565 - accuracy: 0.8745 - val_loss: 0.2053 - val_accuracy: 0.9500
# Epoch 185/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3533 - accuracy: 0.8787 - val_loss: 0.2052 - val_accuracy: 0.9500
# Epoch 186/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3542 - accuracy: 0.8745 - val_loss: 0.2046 - val_accuracy: 0.9500
# Epoch 187/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3544 - accuracy: 0.8828 - val_loss: 0.2036 - val_accuracy: 0.9500
# Epoch 188/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3542 - accuracy: 0.8828 - val_loss: 0.2040 - val_accuracy: 0.9500
# Epoch 189/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3560 - accuracy: 0.8787 - val_loss: 0.2051 - val_accuracy: 0.9500
# Epoch 190/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3569 - accuracy: 0.8787 - val_loss: 0.2035 - val_accuracy: 0.9500
# Epoch 191/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3565 - accuracy: 0.8661 - val_loss: 0.2055 - val_accuracy: 0.9500
# Epoch 192/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3523 - accuracy: 0.8703 - val_loss: 0.2043 - val_accuracy: 0.9500
# Epoch 193/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3515 - accuracy: 0.8870 - val_loss: 0.2030 - val_accuracy: 0.9500
# Epoch 194/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3506 - accuracy: 0.8745 - val_loss: 0.2048 - val_accuracy: 0.9500
# Epoch 195/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3532 - accuracy: 0.8745 - val_loss: 0.2040 - val_accuracy: 0.9500
# Epoch 196/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3488 - accuracy: 0.8787 - val_loss: 0.2030 - val_accuracy: 0.9500
# Epoch 197/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3489 - accuracy: 0.8787 - val_loss: 0.2026 - val_accuracy: 0.9500
# Epoch 198/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3494 - accuracy: 0.8787 - val_loss: 0.2023 - val_accuracy: 0.9500
# Epoch 199/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3479 - accuracy: 0.8870 - val_loss: 0.2023 - val_accuracy: 0.9500
# Epoch 200/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3493 - accuracy: 0.8745 - val_loss: 0.2039 - val_accuracy: 0.9500
# Epoch 201/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3504 - accuracy: 0.8745 - val_loss: 0.2025 - val_accuracy: 0.9500
# Epoch 202/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3485 - accuracy: 0.8745 - val_loss: 0.2015 - val_accuracy: 0.9500
# Epoch 203/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3485 - accuracy: 0.8870 - val_loss: 0.2000 - val_accuracy: 0.9500
# Epoch 204/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3568 - accuracy: 0.8703 - val_loss: 0.2024 - val_accuracy: 0.9500
# Epoch 205/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3531 - accuracy: 0.8828 - val_loss: 0.1989 - val_accuracy: 0.9500
# Epoch 206/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3490 - accuracy: 0.8870 - val_loss: 0.2012 - val_accuracy: 0.9500
# Epoch 207/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3517 - accuracy: 0.8828 - val_loss: 0.1997 - val_accuracy: 0.9500
# Epoch 208/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3402 - accuracy: 0.8828 - val_loss: 0.2028 - val_accuracy: 0.9500
# Epoch 209/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3490 - accuracy: 0.8703 - val_loss: 0.2022 - val_accuracy: 0.9500
# Epoch 210/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3427 - accuracy: 0.8870 - val_loss: 0.1994 - val_accuracy: 0.9500
# Epoch 211/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3423 - accuracy: 0.8828 - val_loss: 0.2008 - val_accuracy: 0.9500
# Epoch 212/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3415 - accuracy: 0.8870 - val_loss: 0.2001 - val_accuracy: 0.9500
# Epoch 213/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3427 - accuracy: 0.8870 - val_loss: 0.1994 - val_accuracy: 0.9500
# Epoch 214/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3407 - accuracy: 0.8912 - val_loss: 0.2008 - val_accuracy: 0.9500
# Epoch 215/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3426 - accuracy: 0.8870 - val_loss: 0.2009 - val_accuracy: 0.9500
# Epoch 216/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3386 - accuracy: 0.8912 - val_loss: 0.1984 - val_accuracy: 0.9500
# Epoch 217/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3412 - accuracy: 0.8912 - val_loss: 0.1987 - val_accuracy: 0.9500
# Epoch 218/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3387 - accuracy: 0.8870 - val_loss: 0.1997 - val_accuracy: 0.9500
# Epoch 219/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3412 - accuracy: 0.8870 - val_loss: 0.1997 - val_accuracy: 0.9500
# Epoch 220/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3397 - accuracy: 0.8912 - val_loss: 0.1986 - val_accuracy: 0.9500
# Epoch 221/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3396 - accuracy: 0.8912 - val_loss: 0.1973 - val_accuracy: 0.9500
# Epoch 222/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3416 - accuracy: 0.8912 - val_loss: 0.2003 - val_accuracy: 0.9500
# Epoch 223/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3401 - accuracy: 0.8912 - val_loss: 0.1973 - val_accuracy: 0.9500
# Epoch 224/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3390 - accuracy: 0.8828 - val_loss: 0.1990 - val_accuracy: 0.9500
# Epoch 225/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3370 - accuracy: 0.8828 - val_loss: 0.1995 - val_accuracy: 0.9500
# Epoch 226/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3344 - accuracy: 0.8954 - val_loss: 0.1981 - val_accuracy: 0.9500
# Epoch 227/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3341 - accuracy: 0.8912 - val_loss: 0.1959 - val_accuracy: 0.9500
# Epoch 228/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3356 - accuracy: 0.8954 - val_loss: 0.1973 - val_accuracy: 0.9500
# Epoch 229/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3369 - accuracy: 0.8787 - val_loss: 0.2000 - val_accuracy: 0.9500
# Epoch 230/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3316 - accuracy: 0.8954 - val_loss: 0.1947 - val_accuracy: 0.9500
# Epoch 231/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3393 - accuracy: 0.8870 - val_loss: 0.1975 - val_accuracy: 0.9500
# Epoch 232/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3311 - accuracy: 0.8954 - val_loss: 0.1966 - val_accuracy: 0.9500
# Epoch 233/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3324 - accuracy: 0.8954 - val_loss: 0.1978 - val_accuracy: 0.9500
# Epoch 234/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3314 - accuracy: 0.9038 - val_loss: 0.1953 - val_accuracy: 0.9500
# Epoch 235/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3313 - accuracy: 0.9079 - val_loss: 0.1958 - val_accuracy: 0.9500
# Epoch 236/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3397 - accuracy: 0.8870 - val_loss: 0.1952 - val_accuracy: 0.9500
# Epoch 237/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3408 - accuracy: 0.8787 - val_loss: 0.1983 - val_accuracy: 0.9500
# Epoch 238/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3317 - accuracy: 0.8954 - val_loss: 0.1928 - val_accuracy: 0.9500
# Epoch 239/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3354 - accuracy: 0.9038 - val_loss: 0.1979 - val_accuracy: 0.9500
# Epoch 240/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3295 - accuracy: 0.9038 - val_loss: 0.1929 - val_accuracy: 0.9500
# Epoch 241/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3281 - accuracy: 0.9038 - val_loss: 0.1937 - val_accuracy: 0.9500
# Epoch 242/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3304 - accuracy: 0.8996 - val_loss: 0.1956 - val_accuracy: 0.9500
# Epoch 243/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3255 - accuracy: 0.8996 - val_loss: 0.1943 - val_accuracy: 0.9500
# Epoch 244/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3255 - accuracy: 0.8996 - val_loss: 0.1949 - val_accuracy: 0.9500
# Epoch 245/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3257 - accuracy: 0.9079 - val_loss: 0.1939 - val_accuracy: 0.9500
# Epoch 246/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3284 - accuracy: 0.9038 - val_loss: 0.1938 - val_accuracy: 0.9500
# Epoch 247/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3328 - accuracy: 0.8996 - val_loss: 0.1899 - val_accuracy: 0.9500
# Epoch 248/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3337 - accuracy: 0.8870 - val_loss: 0.1937 - val_accuracy: 0.9500
# Epoch 249/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3277 - accuracy: 0.8996 - val_loss: 0.1915 - val_accuracy: 0.9500
# Epoch 250/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3304 - accuracy: 0.9038 - val_loss: 0.1939 - val_accuracy: 0.9500
# Epoch 251/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3291 - accuracy: 0.8912 - val_loss: 0.1919 - val_accuracy: 0.9500
# Epoch 252/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3258 - accuracy: 0.9038 - val_loss: 0.1943 - val_accuracy: 0.9500
# Epoch 253/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3208 - accuracy: 0.9163 - val_loss: 0.1918 - val_accuracy: 0.9500
# Epoch 254/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3232 - accuracy: 0.8996 - val_loss: 0.1920 - val_accuracy: 0.9500
# Epoch 255/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3255 - accuracy: 0.8954 - val_loss: 0.1900 - val_accuracy: 0.9500
# Epoch 256/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3226 - accuracy: 0.8954 - val_loss: 0.1904 - val_accuracy: 0.9500
# Epoch 257/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3210 - accuracy: 0.9038 - val_loss: 0.1923 - val_accuracy: 0.9500
# Epoch 258/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3197 - accuracy: 0.8954 - val_loss: 0.1891 - val_accuracy: 0.9500
# Epoch 259/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3184 - accuracy: 0.9038 - val_loss: 0.1906 - val_accuracy: 0.9500
# Epoch 260/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3171 - accuracy: 0.9079 - val_loss: 0.1918 - val_accuracy: 0.9500
# Epoch 261/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3173 - accuracy: 0.9121 - val_loss: 0.1893 - val_accuracy: 0.9500
# Epoch 262/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3155 - accuracy: 0.9079 - val_loss: 0.1895 - val_accuracy: 0.9500
# Epoch 263/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3171 - accuracy: 0.9038 - val_loss: 0.1905 - val_accuracy: 0.9500
# Epoch 264/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3194 - accuracy: 0.9079 - val_loss: 0.1885 - val_accuracy: 0.9500
# Epoch 265/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3346 - accuracy: 0.8912 - val_loss: 0.1904 - val_accuracy: 0.9500
# Epoch 266/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3179 - accuracy: 0.9038 - val_loss: 0.1844 - val_accuracy: 0.9500
# Epoch 267/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3149 - accuracy: 0.8954 - val_loss: 0.1906 - val_accuracy: 0.9500
# Epoch 268/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3205 - accuracy: 0.8996 - val_loss: 0.1886 - val_accuracy: 0.9500
# Epoch 269/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3193 - accuracy: 0.9121 - val_loss: 0.1859 - val_accuracy: 0.9500
# Epoch 270/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3132 - accuracy: 0.9079 - val_loss: 0.1874 - val_accuracy: 0.9500
# Epoch 271/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3143 - accuracy: 0.8996 - val_loss: 0.1858 - val_accuracy: 0.9500
# Epoch 272/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3103 - accuracy: 0.9079 - val_loss: 0.1882 - val_accuracy: 0.9500
# Epoch 273/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3122 - accuracy: 0.9163 - val_loss: 0.1876 - val_accuracy: 0.9500
# Epoch 274/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3103 - accuracy: 0.9121 - val_loss: 0.1866 - val_accuracy: 0.9500
# Epoch 275/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3094 - accuracy: 0.9163 - val_loss: 0.1860 - val_accuracy: 0.9500
# Epoch 276/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3100 - accuracy: 0.9079 - val_loss: 0.1872 - val_accuracy: 0.9500
# Epoch 277/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3105 - accuracy: 0.9079 - val_loss: 0.1836 - val_accuracy: 0.9500
# Epoch 278/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3146 - accuracy: 0.8954 - val_loss: 0.1851 - val_accuracy: 0.9500
# Epoch 279/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3107 - accuracy: 0.9121 - val_loss: 0.1858 - val_accuracy: 0.9500
# Epoch 280/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3060 - accuracy: 0.9121 - val_loss: 0.1870 - val_accuracy: 0.9500
# Epoch 281/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3065 - accuracy: 0.9121 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 282/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3154 - accuracy: 0.8996 - val_loss: 0.1850 - val_accuracy: 0.9500
# Epoch 283/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3077 - accuracy: 0.9205 - val_loss: 0.1877 - val_accuracy: 0.9500
# Epoch 284/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3072 - accuracy: 0.9121 - val_loss: 0.1810 - val_accuracy: 0.9500
# Epoch 285/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3061 - accuracy: 0.9079 - val_loss: 0.1864 - val_accuracy: 0.9500
# Epoch 286/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3082 - accuracy: 0.9079 - val_loss: 0.1822 - val_accuracy: 0.9500
# Epoch 287/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3099 - accuracy: 0.8996 - val_loss: 0.1847 - val_accuracy: 0.9500
# Epoch 288/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3077 - accuracy: 0.9079 - val_loss: 0.1845 - val_accuracy: 0.9500
# Epoch 289/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3060 - accuracy: 0.9038 - val_loss: 0.1792 - val_accuracy: 0.9500
# Epoch 290/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3177 - accuracy: 0.8912 - val_loss: 0.1839 - val_accuracy: 0.9500
# Epoch 291/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3098 - accuracy: 0.9079 - val_loss: 0.1779 - val_accuracy: 0.9500
# Epoch 292/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3066 - accuracy: 0.9121 - val_loss: 0.1847 - val_accuracy: 0.9500
# Epoch 293/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3056 - accuracy: 0.9079 - val_loss: 0.1811 - val_accuracy: 0.9500
# Epoch 294/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3021 - accuracy: 0.9038 - val_loss: 0.1838 - val_accuracy: 0.9500
# Epoch 295/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3011 - accuracy: 0.9121 - val_loss: 0.1780 - val_accuracy: 0.9500
# Epoch 296/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3035 - accuracy: 0.9163 - val_loss: 0.1806 - val_accuracy: 0.9500
# Epoch 297/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3033 - accuracy: 0.9079 - val_loss: 0.1810 - val_accuracy: 0.9500
# Epoch 298/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2982 - accuracy: 0.9038 - val_loss: 0.1774 - val_accuracy: 0.9500
# Epoch 299/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3011 - accuracy: 0.9079 - val_loss: 0.1829 - val_accuracy: 0.9500
# Epoch 300/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2980 - accuracy: 0.9163 - val_loss: 0.1808 - val_accuracy: 0.9500
# Epoch 301/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3035 - accuracy: 0.9121 - val_loss: 0.1794 - val_accuracy: 0.9500
# Epoch 302/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2956 - accuracy: 0.9163 - val_loss: 0.1826 - val_accuracy: 0.9500
# Epoch 303/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2993 - accuracy: 0.9038 - val_loss: 0.1791 - val_accuracy: 0.9500
# Epoch 304/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2995 - accuracy: 0.9121 - val_loss: 0.1780 - val_accuracy: 0.9500
# Epoch 305/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3030 - accuracy: 0.9079 - val_loss: 0.1820 - val_accuracy: 0.9500
# Epoch 306/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2967 - accuracy: 0.9163 - val_loss: 0.1743 - val_accuracy: 0.9500
# Epoch 307/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2991 - accuracy: 0.8996 - val_loss: 0.1778 - val_accuracy: 0.9500
# Epoch 308/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2930 - accuracy: 0.9163 - val_loss: 0.1728 - val_accuracy: 0.9500
# Epoch 309/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2991 - accuracy: 0.9163 - val_loss: 0.1805 - val_accuracy: 0.9500
# Epoch 310/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2946 - accuracy: 0.9163 - val_loss: 0.1770 - val_accuracy: 0.9500
# Epoch 311/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2955 - accuracy: 0.9079 - val_loss: 0.1779 - val_accuracy: 0.9500
# Epoch 312/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2963 - accuracy: 0.9038 - val_loss: 0.1776 - val_accuracy: 0.9500
# Epoch 313/1000
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2929 - accuracy: 0.9163 - val_loss: 0.1731 - val_accuracy: 0.9500
# Epoch 314/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2905 - accuracy: 0.9163 - val_loss: 0.1764 - val_accuracy: 0.9500
# Epoch 315/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3026 - accuracy: 0.8996 - val_loss: 0.1740 - val_accuracy: 0.9500
# Epoch 316/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2909 - accuracy: 0.9163 - val_loss: 0.1721 - val_accuracy: 0.9500
# Epoch 317/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2941 - accuracy: 0.9079 - val_loss: 0.1739 - val_accuracy: 0.9500
# Epoch 318/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2890 - accuracy: 0.9205 - val_loss: 0.1738 - val_accuracy: 0.9500
# Epoch 319/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2920 - accuracy: 0.9163 - val_loss: 0.1760 - val_accuracy: 0.9500
# Epoch 320/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2888 - accuracy: 0.9163 - val_loss: 0.1741 - val_accuracy: 0.9500
# Epoch 321/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2900 - accuracy: 0.9163 - val_loss: 0.1732 - val_accuracy: 0.9500
# Epoch 322/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2894 - accuracy: 0.9163 - val_loss: 0.1727 - val_accuracy: 0.9500
# Epoch 323/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2886 - accuracy: 0.9079 - val_loss: 0.1764 - val_accuracy: 0.9500
# Epoch 324/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2889 - accuracy: 0.9163 - val_loss: 0.1741 - val_accuracy: 0.9500
# Epoch 325/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2896 - accuracy: 0.9121 - val_loss: 0.1745 - val_accuracy: 0.9500
# Epoch 326/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2881 - accuracy: 0.9121 - val_loss: 0.1734 - val_accuracy: 0.9500
# Epoch 327/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2871 - accuracy: 0.9121 - val_loss: 0.1719 - val_accuracy: 0.9500
# Epoch 328/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2900 - accuracy: 0.9205 - val_loss: 0.1716 - val_accuracy: 0.9500
# Epoch 329/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2863 - accuracy: 0.9163 - val_loss: 0.1714 - val_accuracy: 0.9500
# Epoch 330/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2938 - accuracy: 0.8996 - val_loss: 0.1723 - val_accuracy: 0.9500
# Epoch 331/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2860 - accuracy: 0.9163 - val_loss: 0.1686 - val_accuracy: 0.9500
# Epoch 332/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2878 - accuracy: 0.9163 - val_loss: 0.1719 - val_accuracy: 0.9500
# Epoch 333/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2857 - accuracy: 0.9163 - val_loss: 0.1743 - val_accuracy: 0.9500
# Epoch 334/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2894 - accuracy: 0.9038 - val_loss: 0.1704 - val_accuracy: 0.9500
# Epoch 335/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2877 - accuracy: 0.9079 - val_loss: 0.1682 - val_accuracy: 0.9500
# Epoch 336/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2822 - accuracy: 0.9163 - val_loss: 0.1735 - val_accuracy: 0.9500
# Epoch 337/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2847 - accuracy: 0.9121 - val_loss: 0.1721 - val_accuracy: 0.9500
# Epoch 338/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2834 - accuracy: 0.9163 - val_loss: 0.1687 - val_accuracy: 0.9500
# Epoch 339/1000
# ...
# Epoch 889/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2152 - accuracy: 0.9456 - val_loss: 0.1905 - val_accuracy: 0.9500
# Epoch 890/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2156 - accuracy: 0.9456 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 891/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2154 - accuracy: 0.9456 - val_loss: 0.1854 - val_accuracy: 0.9500
# Epoch 892/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2154 - accuracy: 0.9456 - val_loss: 0.1857 - val_accuracy: 0.9500
# Epoch 893/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2154 - accuracy: 0.9456 - val_loss: 0.1811 - val_accuracy: 0.9500
# Epoch 894/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2153 - accuracy: 0.9456 - val_loss: 0.1897 - val_accuracy: 0.9500
# Epoch 895/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2150 - accuracy: 0.9456 - val_loss: 0.1887 - val_accuracy: 0.9500
# Epoch 896/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2150 - accuracy: 0.9456 - val_loss: 0.1899 - val_accuracy: 0.9500
# Epoch 897/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2151 - accuracy: 0.9456 - val_loss: 0.1868 - val_accuracy: 0.9500
# Epoch 898/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2148 - accuracy: 0.9456 - val_loss: 0.1847 - val_accuracy: 0.9500
# Epoch 899/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2150 - accuracy: 0.9456 - val_loss: 0.1860 - val_accuracy: 0.9500
# Epoch 900/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2153 - accuracy: 0.9456 - val_loss: 0.1884 - val_accuracy: 0.9500
# Epoch 901/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2151 - accuracy: 0.9456 - val_loss: 0.1812 - val_accuracy: 0.9500
# Epoch 902/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2153 - accuracy: 0.9456 - val_loss: 0.1857 - val_accuracy: 0.9500
# Epoch 903/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2149 - accuracy: 0.9456 - val_loss: 0.1842 - val_accuracy: 0.9500
# Epoch 904/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2148 - accuracy: 0.9456 - val_loss: 0.1898 - val_accuracy: 0.9500
# Epoch 905/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2148 - accuracy: 0.9456 - val_loss: 0.1881 - val_accuracy: 0.9500
# Epoch 906/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2147 - accuracy: 0.9456 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 907/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2149 - accuracy: 0.9456 - val_loss: 0.1876 - val_accuracy: 0.9500
# Epoch 908/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2147 - accuracy: 0.9456 - val_loss: 0.1857 - val_accuracy: 0.9500
# Epoch 909/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1873 - val_accuracy: 0.9500
# Epoch 910/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1864 - val_accuracy: 0.9500
# Epoch 911/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2148 - accuracy: 0.9456 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 912/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1879 - val_accuracy: 0.9500
# Epoch 913/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 914/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2147 - accuracy: 0.9456 - val_loss: 0.1866 - val_accuracy: 0.9500
# Epoch 915/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1885 - val_accuracy: 0.9500
# Epoch 916/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1831 - val_accuracy: 0.9500
# Epoch 917/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2148 - accuracy: 0.9456 - val_loss: 0.1863 - val_accuracy: 0.9500
# Epoch 918/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2147 - accuracy: 0.9456 - val_loss: 0.1869 - val_accuracy: 0.9500
# Epoch 919/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2145 - accuracy: 0.9456 - val_loss: 0.1869 - val_accuracy: 0.9500
# Epoch 920/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1893 - val_accuracy: 0.9500
# Epoch 921/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2150 - accuracy: 0.9456 - val_loss: 0.1840 - val_accuracy: 0.9500
# Epoch 922/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1891 - val_accuracy: 0.9500
# Epoch 923/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2149 - accuracy: 0.9456 - val_loss: 0.1843 - val_accuracy: 0.9500
# Epoch 924/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2148 - accuracy: 0.9456 - val_loss: 0.1925 - val_accuracy: 0.9500
# Epoch 925/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2147 - accuracy: 0.9456 - val_loss: 0.1878 - val_accuracy: 0.9500
# Epoch 926/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2145 - accuracy: 0.9456 - val_loss: 0.1894 - val_accuracy: 0.9500
# Epoch 927/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1860 - val_accuracy: 0.9500
# Epoch 928/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2144 - accuracy: 0.9456 - val_loss: 0.1849 - val_accuracy: 0.9500
# Epoch 929/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2142 - accuracy: 0.9456 - val_loss: 0.1879 - val_accuracy: 0.9500
# Epoch 930/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2144 - accuracy: 0.9456 - val_loss: 0.1875 - val_accuracy: 0.9500
# Epoch 931/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1864 - val_accuracy: 0.9500
# Epoch 932/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2143 - accuracy: 0.9456 - val_loss: 0.1871 - val_accuracy: 0.9500
# Epoch 933/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2144 - accuracy: 0.9456 - val_loss: 0.1887 - val_accuracy: 0.9500
# Epoch 934/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2143 - accuracy: 0.9456 - val_loss: 0.1877 - val_accuracy: 0.9500
# Epoch 935/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2142 - accuracy: 0.9456 - val_loss: 0.1857 - val_accuracy: 0.9500
# Epoch 936/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2143 - accuracy: 0.9456 - val_loss: 0.1872 - val_accuracy: 0.9500
# Epoch 937/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2144 - accuracy: 0.9456 - val_loss: 0.1866 - val_accuracy: 0.9500
# Epoch 938/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2142 - accuracy: 0.9456 - val_loss: 0.1882 - val_accuracy: 0.9500
# Epoch 939/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2142 - accuracy: 0.9456 - val_loss: 0.1904 - val_accuracy: 0.9500
# Epoch 940/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2143 - accuracy: 0.9456 - val_loss: 0.1867 - val_accuracy: 0.9500
# Epoch 941/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2145 - accuracy: 0.9456 - val_loss: 0.1898 - val_accuracy: 0.9500
# Epoch 942/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2143 - accuracy: 0.9456 - val_loss: 0.1824 - val_accuracy: 0.9500
# Epoch 943/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2146 - accuracy: 0.9456 - val_loss: 0.1892 - val_accuracy: 0.9500
# Epoch 944/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2142 - accuracy: 0.9456 - val_loss: 0.1874 - val_accuracy: 0.9500
# Epoch 945/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9456 - val_loss: 0.1883 - val_accuracy: 0.9500
# Epoch 946/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1879 - val_accuracy: 0.9500
# Epoch 947/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 948/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1858 - val_accuracy: 0.9500
# Epoch 949/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1886 - val_accuracy: 0.9500
# Epoch 950/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1865 - val_accuracy: 0.9500
# Epoch 951/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1856 - val_accuracy: 0.9500
# Epoch 952/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1878 - val_accuracy: 0.9500
# Epoch 953/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2141 - accuracy: 0.9456 - val_loss: 0.1882 - val_accuracy: 0.9500
# Epoch 954/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1875 - val_accuracy: 0.9500
# Epoch 955/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1886 - val_accuracy: 0.9500
# Epoch 956/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9456 - val_loss: 0.1844 - val_accuracy: 0.9500
# Epoch 957/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2142 - accuracy: 0.9456 - val_loss: 0.1904 - val_accuracy: 0.9500
# Epoch 958/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2138 - accuracy: 0.9456 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 959/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9456 - val_loss: 0.1879 - val_accuracy: 0.9500
# Epoch 960/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1861 - val_accuracy: 0.9500
# Epoch 961/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9456 - val_loss: 0.1884 - val_accuracy: 0.9500
# Epoch 962/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2137 - accuracy: 0.9456 - val_loss: 0.1838 - val_accuracy: 0.9500
# Epoch 963/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1878 - val_accuracy: 0.9500
# Epoch 964/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1869 - val_accuracy: 0.9500
# Epoch 965/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1869 - val_accuracy: 0.9500
# Epoch 966/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1876 - val_accuracy: 0.9500
# Epoch 967/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2137 - accuracy: 0.9456 - val_loss: 0.1871 - val_accuracy: 0.9500
# Epoch 968/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1890 - val_accuracy: 0.9500
# Epoch 969/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1874 - val_accuracy: 0.9500
# Epoch 970/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9456 - val_loss: 0.1897 - val_accuracy: 0.9500
# Epoch 971/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2140 - accuracy: 0.9456 - val_loss: 0.1865 - val_accuracy: 0.9500
# Epoch 972/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2138 - accuracy: 0.9456 - val_loss: 0.1851 - val_accuracy: 0.9500
# Epoch 973/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2137 - accuracy: 0.9456 - val_loss: 0.1869 - val_accuracy: 0.9500
# Epoch 974/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2136 - accuracy: 0.9456 - val_loss: 0.1867 - val_accuracy: 0.9500
# Epoch 975/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2138 - accuracy: 0.9456 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 976/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2136 - accuracy: 0.9456 - val_loss: 0.1898 - val_accuracy: 0.9500
# Epoch 977/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2136 - accuracy: 0.9456 - val_loss: 0.1883 - val_accuracy: 0.9500
# Epoch 978/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2138 - accuracy: 0.9456 - val_loss: 0.1852 - val_accuracy: 0.9500
# Epoch 979/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9456 - val_loss: 0.1897 - val_accuracy: 0.9500
# Epoch 980/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9456 - val_loss: 0.1861 - val_accuracy: 0.9500
# Epoch 981/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2136 - accuracy: 0.9456 - val_loss: 0.1908 - val_accuracy: 0.9500
# Epoch 982/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2137 - accuracy: 0.9456 - val_loss: 0.1866 - val_accuracy: 0.9500
# Epoch 983/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2136 - accuracy: 0.9456 - val_loss: 0.1864 - val_accuracy: 0.9500
# Epoch 984/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2135 - accuracy: 0.9456 - val_loss: 0.1888 - val_accuracy: 0.9500
# Epoch 985/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2135 - accuracy: 0.9456 - val_loss: 0.1885 - val_accuracy: 0.9500
# Epoch 986/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9456 - val_loss: 0.1888 - val_accuracy: 0.9500
# Epoch 987/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9456 - val_loss: 0.1907 - val_accuracy: 0.9500
# Epoch 988/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2136 - accuracy: 0.9456 - val_loss: 0.1842 - val_accuracy: 0.9500
# Epoch 989/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2135 - accuracy: 0.9456 - val_loss: 0.1906 - val_accuracy: 0.9500
# Epoch 990/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.9456 - val_loss: 0.1849 - val_accuracy: 0.9500
# Epoch 991/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9456 - val_loss: 0.1909 - val_accuracy: 0.9500
# Epoch 992/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9456 - val_loss: 0.1907 - val_accuracy: 0.9500
# Epoch 993/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9456 - val_loss: 0.1893 - val_accuracy: 0.9500
# Epoch 994/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9456 - val_loss: 0.1882 - val_accuracy: 0.9500
# Epoch 995/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9456 - val_loss: 0.1869 - val_accuracy: 0.9500
# Epoch 996/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9456 - val_loss: 0.1876 - val_accuracy: 0.9500
# Epoch 997/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2133 - accuracy: 0.9456 - val_loss: 0.1878 - val_accuracy: 0.9500
# Epoch 998/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2135 - accuracy: 0.9456 - val_loss: 0.1861 - val_accuracy: 0.9500
# Epoch 999/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2134 - accuracy: 0.9456 - val_loss: 0.1885 - val_accuracy: 0.9500
# Epoch 1000/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2133 - accuracy: 0.9456 - val_loss: 0.1918 - val_accuracy: 0.9500

# %% [markdown]
# ###2.c) How did the model perform.
# How did your neural network preform? What hyperparameters and optimizer did you choose? What activation did you use?

# %% [markdown]
# #### Answer
# The neural network performed pretty well with a validation accuracy of 95% which is pretty good. I used 5 Dense layers in which 4 are using a tanh activation and the last one a sigmoid activation function. The optimizer is the one that is default (Adam) and the number of nodes per layer is as follows: 25, 15, 7, 1, 1. The neural network seems to have done better than persumed to be cause the traning accuracy and validation are very very close.
